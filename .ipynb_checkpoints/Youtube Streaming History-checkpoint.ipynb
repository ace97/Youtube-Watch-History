# %%
#%matplotlib widget

# %%
import re
import nltk
from nltk.corpus import stopwords
import string
from collections import Counter
import operator

import calendar
import json
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from datetime import timedelta


import warnings
warnings.filterwarnings("ignore")

# %%
file = open("watch-history.json", errors='replace')

# %%
text = file.read()

# %%
type(text)
# Out:
# str

# %%
j=json.loads(text)

# %%
streaming_history = pd.DataFrame(j)

# %%
streaming_history.head(5)
# Out:
#     header                                              title  \
# 0  YouTube  Watched Rahul Subramanian | Crowd work Special...
# 1  YouTube  Watched Nvidia Said No.. I said YES! - The 100...
# 2  YouTube  Watched Biswa Kalyan Rath | Mood Kharaab | New...
# 3  YouTube  Watched Lucky Lefty OR: I Lost My Right Nut An...
# 4  YouTube  Watched Is A Runaway Black Hole Creating A Tra...
#
#                                       titleUrl  \
# 0  https://www.youtube.com/watch?v=7dRjFxqCCQk
# 1  https://www.youtube.com/watch?v=vz-rpRYFhRo
# 2  https://www.youtube.com/watch?v=V_c-oLhaR_4
# 3  https://www.youtube.com/watch?v=A2Rdh82XGrY
# 4  https://www.youtube.com/watch?v=UYVUPd3_Fus
#
#                                            subtitles  \
# 0  [{'name': 'Random Chikibum', 'url': 'https://w...
# 1  [{'name': 'Linus Tech Tips', 'url': 'https://w...
# 2  [{'name': 'Biswa Kalyan Rath', 'url': 'https:/...
# 3  [{'name': 'Nimesh Patel', 'url': 'https://www....
# 4  [{'name': 'StarTalk', 'url': 'https://www.yout...
#
#                        time   products         activityControls
# 0  2023-05-04T23:34:00.079Z  [YouTube]  [YouTube watch history]
# 1  2023-05-04T21:45:23.215Z  [YouTube]  [YouTube watch history]
# 2  2023-05-04T21:43:48.572Z  [YouTube]  [YouTube watch history]
# 3  2023-05-03T03:09:38.598Z  [YouTube]  [YouTube watch history]
# 4  2023-05-03T03:09:24.708Z  [YouTube]  [YouTube watch history]

# %%
streaming_history.time = pd.to_datetime(streaming_history.time)

# %%
streaming_history
# Out:
#        header                                              title  \
# 0     YouTube  Watched Rahul Subramanian | Crowd work Special...
# 1     YouTube  Watched Nvidia Said No.. I said YES! - The 100...
# 2     YouTube  Watched Biswa Kalyan Rath | Mood Kharaab | New...
# 3     YouTube  Watched Lucky Lefty OR: I Lost My Right Nut An...
# 4     YouTube  Watched Is A Runaway Black Hole Creating A Tra...
# ...       ...                                                ...
# 4775  YouTube  Watched I PUT TENZ ON MY BACK. HARD CARRY MODE...
# 4776  YouTube  Watched 11 minutes of Shroud playing against o...
# 4777  YouTube  Watched I've never felt this way before - $60 ...
# 4778  YouTube  Watched I Tried to Break a Million Dollar Comp...
# 4779  YouTube  Watched Sterling K. Brown Explains His "No Gym...
#
#                                          titleUrl  \
# 0     https://www.youtube.com/watch?v=7dRjFxqCCQk
# 1     https://www.youtube.com/watch?v=vz-rpRYFhRo
# 2     https://www.youtube.com/watch?v=V_c-oLhaR_4
# 3     https://www.youtube.com/watch?v=A2Rdh82XGrY
# 4     https://www.youtube.com/watch?v=UYVUPd3_Fus
# ...                                           ...
# 4775  https://www.youtube.com/watch?v=EQbdDLWs-4U
# 4776  https://www.youtube.com/watch?v=WBBedUaEU2o
# 4777  https://www.youtube.com/watch?v=jGyHT0t-mtw
# 4778  https://www.youtube.com/watch?v=ZDtaanCENbc
# 4779  https://www.youtube.com/watch?v=PVr9fU2Kgjs
#
#                                               subtitles  \
# 0     [{'name': 'Random Chikibum', 'url': 'https://w...
# 1     [{'name': 'Linus Tech Tips', 'url': 'https://w...
# 2     [{'name': 'Biswa Kalyan Rath', 'url': 'https:/...
# 3     [{'name': 'Nimesh Patel', 'url': 'https://www....
# 4     [{'name': 'StarTalk', 'url': 'https://www.yout...
# ...                                                 ...
# 4775  [{'name': 'ShahZaM', 'url': 'https://www.youtu...
# 4776  [{'name': 'Shroud', 'url': 'https://www.youtub...
# 4777  [{'name': 'Linus Tech Tips', 'url': 'https://w...
# 4778  [{'name': 'Linus Tech Tips', 'url': 'https://w...
# 4779  [{'name': 'Men's Health', 'url': 'https://www....
#
#                                  time   products         activityControls
# 0    2023-05-04 23:34:00.079000+00:00  [YouTube]  [YouTube watch history]
# 1    2023-05-04 21:45:23.215000+00:00  [YouTube]  [YouTube watch history]
# 2    2023-05-04 21:43:48.572000+00:00  [YouTube]  [YouTube watch history]
# 3    2023-05-03 03:09:38.598000+00:00  [YouTube]  [YouTube watch history]
# 4    2023-05-03 03:09:24.708000+00:00  [YouTube]  [YouTube watch history]
# ...                               ...        ...                      ...
# 4775 2022-04-06 03:59:37.555000+00:00  [YouTube]  [YouTube watch history]
# 4776 2022-04-06 01:31:44.390000+00:00  [YouTube]  [YouTube watch history]
# 4777 2022-04-06 00:46:50.131000+00:00  [YouTube]  [YouTube watch history]
# 4778 2022-04-06 00:06:52.861000+00:00  [YouTube]  [YouTube watch history]
# 4779 2022-04-05 22:20:16.371000+00:00  [YouTube]  [YouTube watch history]
#
# [4780 rows x 7 columns]

# %%
streaming_history["date"] = streaming_history["time"].dt.floor('d')

# %%
#saving yt history as csv file
#streaming_history.to_csv("watch-history.csv",index=False)

# %%
by_date = streaming_history.groupby("date")[["title"]].count()
by_date = by_date.sort_index()

# %%
by_date.index
# Out:
# DatetimeIndex(['2022-04-05 00:00:00+00:00', '2022-04-06 00:00:00+00:00',
#                '2022-04-07 00:00:00+00:00', '2022-04-08 00:00:00+00:00',
#                '2022-04-09 00:00:00+00:00', '2022-04-10 00:00:00+00:00',
#                '2022-04-11 00:00:00+00:00', '2022-04-12 00:00:00+00:00',
#                '2022-04-13 00:00:00+00:00', '2022-04-14 00:00:00+00:00',
#                ...
#                '2023-04-24 00:00:00+00:00', '2023-04-25 00:00:00+00:00',
#                '2023-04-26 00:00:00+00:00', '2023-04-27 00:00:00+00:00',
#                '2023-04-28 00:00:00+00:00', '2023-04-29 00:00:00+00:00',
#                '2023-05-01 00:00:00+00:00', '2023-05-02 00:00:00+00:00',
#                '2023-05-03 00:00:00+00:00', '2023-05-04 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='date', length=380, freq=None)

# %%
by_date["weekday"] = by_date.index.weekday
by_date["week"] = by_date.index.week

# %%
by_date.title.sum()
# Out:
# 4780

# %%
week = 0
prev_week = by_date.iloc[0]["week"]
continuous_week = np.zeros(len(by_date)).astype(int)
sunday_dates = []
for i, (_, row) in enumerate(by_date.iterrows()):
    if row["week"] != prev_week:
        week += 1
        prev_week = row["week"]
    continuous_week[i] = week
by_date["continuous_week"] = continuous_week 
continuous_week.sum()
# Out:
# 10587

# %%
videos = np.full((7, continuous_week.max()+1), np.nan)

for index, row in by_date.iterrows():
    videos[row["weekday"]][row["continuous_week"]] = row["title"]

# %%
fig = plt.figure(figsize=(20,5))
ax = plt.subplot()
mask = np.isnan(videos)
sns.heatmap(videos, ax = ax)
# Out:
# <Axes: >

# %%
min_date = streaming_history["time"].min()
first_monday = min_date - timedelta(min_date.weekday())
mons = [first_monday + timedelta(weeks=wk) for wk in range(continuous_week.max())]
x_labels = [calendar.month_abbr[mons[0].month]]
x_labels.extend([
    calendar.month_abbr[mons[i].month] if mons[i-1].month != mons[i].month else "" 
    for i in range(1, len(mons))])
x_labels.append("") 
y_labels = ["Mon", "Tue", "Wed", "Thur", "Fri", "Sat", "Sun"]

# %%
fig = plt.figure(figsize=(25,10))
ax = plt.subplot()

ax.set_title("My year on Youtube", fontsize=20,pad=40)
ax.xaxis.tick_top()
ax.tick_params(axis='both', which='both',length=0)
ax.set_facecolor("#ebedf0") 
fig.patch.set_facecolor('white')


sns.heatmap(videos, linewidths=5, linecolor='white', square=True,
            mask=np.isnan(videos), cmap="Reds",
            vmin=0, vmax=100, cbar=True, ax=ax)


ax.set_xticklabels(x_labels, ha="left")
ax.set_yticklabels(y_labels, rotation=0)
# Out:
# [Text(0, 0.5, 'Mon'),
#  Text(0, 1.5, 'Tue'),
#  Text(0, 2.5, 'Wed'),
#  Text(0, 3.5, 'Thur'),
#  Text(0, 4.5, 'Fri'),
#  Text(0, 5.5, 'Sat'),
#  Text(0, 6.5, 'Sun')]

# %%
#!! streamlit run yt_history.py

# %%
#streaming_history[streaming_history["header"]=='YouTube']

# %% [markdown]
# ## Youtube Videos

# %%
len(streaming_history.query('header == "YouTube"'))
# Out:
# 3702

# %%
#get index of rows where 'header' column is equal to 'Youtube'
by_date1 = streaming_history.query('header=="YouTube"').groupby("date")[["title"]].count()
by_date1 = by_date1.sort_index()

# %%
by_date1["weekday"] = by_date1.index.weekday
by_date1["week"] = by_date1.index.week

# %%
by_date1
# Out:
#                            title  weekday  week
# date
# 2022-04-05 00:00:00+00:00      1        1    14
# 2022-04-06 00:00:00+00:00      9        2    14
# 2022-04-07 00:00:00+00:00      6        3    14
# 2022-04-08 00:00:00+00:00      2        4    14
# 2022-04-09 00:00:00+00:00      7        5    14
# ...                          ...      ...   ...
# 2023-04-29 00:00:00+00:00      2        5    17
# 2023-05-01 00:00:00+00:00      4        0    18
# 2023-05-02 00:00:00+00:00     13        1    18
# 2023-05-03 00:00:00+00:00     31        2    18
# 2023-05-04 00:00:00+00:00      3        3    18
#
# [377 rows x 3 columns]

# %%
week1 = 0
prev_week1 = by_date1.iloc[0]["week"]
continuous_week1 = np.zeros(len(by_date1)).astype(int)
for i, (_, row) in enumerate(by_date1.iterrows()):
    if row["week"] != prev_week1:
        week1 += 1
        prev_week1 = row["week"]
    continuous_week1[i] = week1
by_date1["continuous_week"] = continuous_week1

# %%
videos1 = np.full((7, continuous_week1.max()+1), np.nan)

for index1, row in by_date1.iterrows():
    videos1[row["weekday"]][row["continuous_week"]] = row["title"]

# %%
fig1 = plt.figure(figsize=(25,10))
ax1 = plt.subplot()

ax1.set_title("Youtube Videos", fontsize=20,pad=40)
ax1.xaxis.tick_top()
ax1.tick_params(axis='both', which='both',length=0)



sns.heatmap(videos1, linewidths=5, linecolor='white', square=True,
            mask=np.isnan(videos), cmap="Reds",
            vmin=0, vmax=100, cbar=True, ax=ax1)


ax1.set_xticklabels(x_labels, ha="left")
ax1.set_yticklabels(y_labels, rotation=0)
# Out:
# [Text(0, 0.5, 'Mon'),
#  Text(0, 1.5, 'Tue'),
#  Text(0, 2.5, 'Wed'),
#  Text(0, 3.5, 'Thur'),
#  Text(0, 4.5, 'Fri'),
#  Text(0, 5.5, 'Sat'),
#  Text(0, 6.5, 'Sun')]

# %% [markdown]
# ## Youtube Music

# %%
len(streaming_history.query('header == "YouTube Music"'))
# Out:
# 1078

# %%
#get index of rows where 'header' column is equal to 'Youtube Music'
by_date2 = streaming_history.query('header=="YouTube Music"').groupby("date")[["title"]].count()
by_date2 = by_date2.sort_index()

# %%
by_date2["weekday"] = by_date2.index.weekday
by_date2["week"] = by_date2.index.week

# %%
by_date2
# Out:
#                            title  weekday  week
# date
# 2022-04-11 00:00:00+00:00      5        0    15
# 2022-04-15 00:00:00+00:00      4        4    15
# 2022-04-23 00:00:00+00:00     17        5    16
# 2022-04-27 00:00:00+00:00     13        2    17
# 2022-05-02 00:00:00+00:00     35        0    18
# ...                          ...      ...   ...
# 2023-04-13 00:00:00+00:00     30        3    15
# 2023-04-16 00:00:00+00:00     19        6    15
# 2023-04-20 00:00:00+00:00      6        3    16
# 2023-04-23 00:00:00+00:00     21        6    16
# 2023-04-29 00:00:00+00:00     56        5    17
#
# [103 rows x 3 columns]

# %%
week2 = 0
prev_week2 = by_date2.iloc[0]["week"]
continuous_week2 = np.zeros(len(by_date2)).astype(int)
for i, (_, row) in enumerate(by_date2.iterrows()):
    if row["week"] != prev_week2:
        week2 += 1
        prev_week2 = row["week"]
    continuous_week2[i] = week2
by_date2["continuous_week"] = continuous_week2

# %%
videos2 = np.full((7, continuous_week2.max()+1), np.nan)

for index2, row in by_date2.iterrows():
    videos2[row["weekday"]][row["continuous_week"]] = row["title"]

# %%
x_labels2 = [calendar.month_abbr[mons[0].month]]
x_labels2.extend([
    calendar.month_abbr[mons[i].month] if mons[i-1].month != mons[i].month else "" 
    for i in range(1, 43)])
#x_labels2.append("") 
len(x_labels2)
# Out:
# 43

# %%
fig2 = plt.figure(figsize=(25,10))
ax2 = plt.subplot()

ax2.set_title("Youtube Music", fontsize=20,pad=40)
ax2.xaxis.tick_top()
ax2.tick_params(axis='both', which='both',length=0)



sns.heatmap(videos2, linewidths=5, linecolor='white', square=True,
            mask=np.isnan(videos2), cmap="Reds",
            vmin=0, vmax=100, cbar=True, ax=ax2)


ax2.set_xticklabels(x_labels2, ha="left")
ax2.set_yticklabels(y_labels, rotation=0)
# Out:
# [Text(0, 0.5, 'Mon'),
#  Text(0, 1.5, 'Tue'),
#  Text(0, 2.5, 'Wed'),
#  Text(0, 3.5, 'Thur'),
#  Text(0, 4.5, 'Fri'),
#  Text(0, 5.5, 'Sat'),
#  Text(0, 6.5, 'Sun')]

# %%
#!! streamlit run yt_history.py

# %%
df = pd.DataFrame(j)

# %%
df.time = pd.to_datetime(df.time)

# %%
df.head()
# Out:
#     header                                              title  \
# 0  YouTube  Watched Rahul Subramanian | Crowd work Special...
# 1  YouTube  Watched Nvidia Said No.. I said YES! - The 100...
# 2  YouTube  Watched Biswa Kalyan Rath | Mood Kharaab | New...
# 3  YouTube  Watched Lucky Lefty OR: I Lost My Right Nut An...
# 4  YouTube  Watched Is A Runaway Black Hole Creating A Tra...
#
#                                       titleUrl  \
# 0  https://www.youtube.com/watch?v=7dRjFxqCCQk
# 1  https://www.youtube.com/watch?v=vz-rpRYFhRo
# 2  https://www.youtube.com/watch?v=V_c-oLhaR_4
# 3  https://www.youtube.com/watch?v=A2Rdh82XGrY
# 4  https://www.youtube.com/watch?v=UYVUPd3_Fus
#
#                                            subtitles  \
# 0  [{'name': 'Random Chikibum', 'url': 'https://w...
# 1  [{'name': 'Linus Tech Tips', 'url': 'https://w...
# 2  [{'name': 'Biswa Kalyan Rath', 'url': 'https:/...
# 3  [{'name': 'Nimesh Patel', 'url': 'https://www....
# 4  [{'name': 'StarTalk', 'url': 'https://www.yout...
#
#                               time   products         activityControls
# 0 2023-05-04 23:34:00.079000+00:00  [YouTube]  [YouTube watch history]
# 1 2023-05-04 21:45:23.215000+00:00  [YouTube]  [YouTube watch history]
# 2 2023-05-04 21:43:48.572000+00:00  [YouTube]  [YouTube watch history]
# 3 2023-05-03 03:09:38.598000+00:00  [YouTube]  [YouTube watch history]
# 4 2023-05-03 03:09:24.708000+00:00  [YouTube]  [YouTube watch history]

# %%
df.shape
# Out:
# (4780, 7)

# %%
df.dtypes
# Out:
# header                           object
# title                            object
# titleUrl                         object
# subtitles                        object
# time                datetime64[ns, UTC]
# products                         object
# activityControls                 object
# dtype: object

# %%
df.isnull().sum()
# Out:
# header               0
# title                0
# titleUrl            21
# subtitles           15
# time                 0
# products             0
# activityControls     0
# dtype: int64

# %%
df.title.nunique()
# Out:
# 3687

# %%
df['time'] = pd.to_datetime(df['time'])
df['hour'] = df['time'].dt.hour
sns.histplot(data=df, x='hour', kde=True)
plt.show()

# %%
products_list = []
for items in df['products']:
    for item in items:
        products_list.append(item)
products_df = pd.DataFrame(products_list, columns=['Product'])
sns.countplot(data=products_df, y='Product')
plt.show()

# %%
by_day = streaming_history.groupby("date")[["title"]].mean()
by_day = by_day.sort_index()

by_day["weekday"] = by_date.index.weekday

# %%
# Convert weekday numbers to day names
day_names = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
by_day['weekday_name'] = by_day['weekday'].apply(lambda x: day_names[x])

# Plot the results
ax = by_day["weekday"].plot(kind='hist', bins=7, edgecolor='black')
ax.set_xticks(range(7))
ax.set_xticklabels(day_names)
ax.set_xlim(-0.25, 6.25)
plt.xlabel('Day of the week')
plt.ylabel('Sum of values')
plt.title('Mean View count by day of the week')
plt.show()

# %%
# Extract the video title column
titles = df['title']

# Define a regular expression pattern to match words
pattern = r'\w+'

# Create a dictionary to store word counts
word_counts = {}

# Loop through each video title
for title in titles:
    # Use regular expression to extract all words from the title
    words = re.findall(pattern, title)
    
    # Loop through each word and update the word count dictionary
    for word in words:
        if word.lower() in word_counts:
            word_counts[word.lower()] += 1
        else:
            word_counts[word.lower()] = 1

# Print the top 10 most frequent words
top_words = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)[:20]
for word, count in top_words:
    print(f'{word}: {count}')
# Out:
# watched: 4761
# the: 1107
# honest: 378
# in: 377
# to: 375
# a: 374
# trailers: 359
# i: 349
# of: 305
# is: 272
# video: 264
# s: 258
# with: 248
# on: 220
# you: 209
# music: 203
# and: 202
# official: 201
# game: 182
# for: 181

# %%
nltk.download('stopwords')

# Define function to preprocess text
def preprocess_text(text):
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Convert to lowercase
    text = text.lower()
    # Tokenize text into words
    words = text.split()
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    return words


titles = df['title']

word_counts=''
# Count words in each title after preprocessing
for title in titles:
    words = preprocess_text(title)
    word_counts = Counter(words)
    print(title)
    print(word_counts)
    print()
# Out:
# Watched Rahul Subramanian | Crowd work Special | Deleted Scenes 2 | Amazon Prime Video
# Counter({'watched': 1, 'rahul': 1, 'subramanian': 1, 'crowd': 1, 'work': 1, 'special': 1, 'deleted': 1, 'scenes': 1, '2': 1, 'amazon': 1, 'prime': 1, 'video': 1})
#
# Watched Nvidia Said No.. I said YES! - The 1000W GPU
# Counter({'said': 2, 'watched': 1, 'nvidia': 1, 'yes': 1, '1000w': 1, 'gpu': 1})
#
# Watched Biswa Kalyan Rath | Mood Kharaab | New Stand Up Special | @PrimeVideoIN
# Counter({'watched': 1, 'biswa': 1, 'kalyan': 1, 'rath': 1, 'mood': 1, 'kharaab': 1, 'new': 1, 'stand': 1, 'special': 1, 'primevideoin': 1})
#
# Watched Lucky Lefty OR: I Lost My Right Nut And All I Got Was This Stupid Special | NIMESH PATEL
# Counter({'watched': 1, 'lucky': 1, 'lefty': 1, 'lost': 1, 'right': 1, 'nut': 1, 'got': 1, 'stupid': 1, 'special': 1, 'nimesh': 1, 'patel': 1})
#
# Watched Is A Runaway Black Hole Creating A Trail of Stars? | Neil deGrasse Tyson Explains...
# Counter({'watched': 1, 'runaway': 1, 'black': 1, 'hole': 1, 'creating': 1, 'trail': 1, 'stars': 1, 'neil': 1, 'degrasse': 1, 'tyson': 1, 'explains': 1})
#
# Watched Eminem - The Real Slim Shady (Official Video - Clean Version)
# Counter({'watched': 1, 'eminem': 1, 'real': 1, 'slim': 1, 'shady': 1, 'official': 1, 'video': 1, 'clean': 1, 'version': 1})
#
# Watched Eminem - Not Afraid
# Counter({'watched': 1, 'eminem': 1, 'afraid': 1})
#
# Watched Eminem - Mockingbird [Official Music Video]
# Counter({'watched': 1, 'eminem': 1, 'mockingbird': 1, 'official': 1, 'music': 1, 'video': 1})
#
# Watched Eminem - Venom
# Counter({'watched': 1, 'eminem': 1, 'venom': 1})
#
# Watched Eminem - Berzerk (Official Music Video) (Explicit)
# Counter({'watched': 1, 'eminem': 1, 'berzerk': 1, 'official': 1, 'music': 1, 'video': 1, 'explicit': 1})
#
# Watched Daft Punk - Get Lucky (Official Audio) ft. Pharrell Williams, Nile Rodgers
# Counter({'watched': 1, 'daft': 1, 'punk': 1, 'get': 1, 'lucky': 1, 'official': 1, 'audio': 1, 'ft': 1, 'pharrell': 1, 'williams': 1, 'nile': 1, 'rodgers': 1})
#
# Watched Bruno Mars - Locked Out Of Heaven (Official Music Video)
# Counter({'watched': 1, 'bruno': 1, 'mars': 1, 'locked': 1, 'heaven': 1, 'official': 1, 'music': 1, 'video': 1})
#
# Watched Swedish House Mafia ft. John Martin - Don't You Worry Child (Official Video)
# Counter({'watched': 1, 'swedish': 1, 'house': 1, 'mafia': 1, 'ft': 1, 'john': 1, 'martin': 1, 'dont': 1, 'worry': 1, 'child': 1, 'official': 1, 'video': 1})
#
# Watched Flo Rida - Good Feeling [Official Video]
# Counter({'watched': 1, 'flo': 1, 'rida': 1, 'good': 1, 'feeling': 1, 'official': 1, 'video': 1})
#
# Watched Flo Rida - Club Can't Handle Me ft. David Guetta [Official Music Video] - Step Up 3D
# Counter({'watched': 1, 'flo': 1, 'rida': 1, 'club': 1, 'cant': 1, 'handle': 1, 'ft': 1, 'david': 1, 'guetta': 1, 'official': 1, 'music': 1, 'video': 1, 'step': 1, '3d': 1})
#
# Watched Eminem - Without Me (Official Music Video)
# Counter({'watched': 1, 'eminem': 1, 'without': 1, 'official': 1, 'music': 1, 'video': 1})
#
# Watched The Black Eyed Peas - I Gotta Feeling (Official Music Video)
# Counter({'watched': 1, 'black': 1, 'eyed': 1, 'peas': 1, 'gotta': 1, 'feeling': 1, 'official': 1, 'music': 1, 'video': 1})
#
# Watched The Black Eyed Peas - Pump It (Official Music Video)
# Counter({'watched': 1, 'black': 1, 'eyed': 1, 'peas': 1, 'pump': 1, 'official': 1, 'music': 1, 'video': 1})
#
# Watched Akon - Smack That (Official Music Video) ft. Eminem
# Counter({'watched': 1, 'akon': 1, 'smack': 1, 'official': 1, 'music': 1, 'video': 1, 'ft': 1, 'eminem': 1})
#
# Watched Akon - Right Now (Na Na Na) (Official Video)
# Counter({'na': 3, 'watched': 1, 'akon': 1, 'right': 1, 'official': 1, 'video': 1})
#
# Watched LMFAO - Party Rock Anthem ft. Lauren Bennett, GoonRock
# Counter({'watched': 1, 'lmfao': 1, 'party': 1, 'rock': 1, 'anthem': 1, 'ft': 1, 'lauren': 1, 'bennett': 1, 'goonrock': 1})
#
# Watched Dua Lipa - Levitating Featuring DaBaby (Official Music Video)
# Counter({'watched': 1, 'dua': 1, 'lipa': 1, 'levitating': 1, 'featuring': 1, 'dababy': 1, 'official': 1, 'music': 1, 'video': 1})
#
# Watched Justin Timberlake - Mirrors (Official Video)
# Counter({'watched': 1, 'justin': 1, 'timberlake': 1, 'mirrors': 1, 'official': 1, 'video': 1})
#
# Watched The Weeknd - Save Your Tears (Official Music Video)
# Counter({'watched': 1, 'weeknd': 1, 'save': 1, 'tears': 1, 'official': 1, 'music': 1, 'video': 1})
#
# Watched Bon Jovi - Livin' On A Prayer
# Counter({'watched': 1, 'bon': 1, 'jovi': 1, 'livin': 1, 'prayer': 1})
#
# Watched Ya Ali - 4K Video Song | Gangster | Emraan H | Kangna R | Zubeen Garg | #HindiSong | Hitz Music
# Counter({'watched': 1, 'ya': 1, 'ali': 1, '4k': 1, 'video': 1, 'song': 1, 'gangster': 1, 'emraan': 1, 'h': 1, 'kangna': 1, 'r': 1, 'zubeen': 1, 'garg': 1, 'hindisong': 1, 'hitz': 1, 'music': 1})
#
# Watched Backstreet Boys - I Want It That Way (Official HD Video)
# Counter({'watched': 1, 'backstreet': 1, 'boys': 1, 'want': 1, 'way': 1, 'official': 1, 'hd': 1, 'video': 1})
#
# Watched Backstreet Boys - Incomplete (Official HD Video)
# Counter({'watched': 1, 'backstreet': 1, 'boys': 1, 'incomplete': 1, 'official': 1, 'hd': 1, 'video': 1})
#
# Watched Numb (Official Music Video) [4K UPGRADE] â€“ Linkin Park
# Counter({'watched': 1, 'numb': 1, 'official': 1, 'music': 1, 'video': 1, '4k': 1, 'upgrade': 1, 'â€“': 1, 'linkin': 1, 'park': 1})
#
# Watched The Chainsmokers - I Love U (Official Video)
# Counter({'watched': 1, 'chainsmokers': 1, 'love': 1, 'u': 1, 'official': 1, 'video': 1})
#
# Watched Brodha V x Jordindian - Vainko [Music Video]
# Counter({'watched': 1, 'brodha': 1, 'v': 1, 'x': 1, 'jordindian': 1, 'vainko': 1, 'music': 1, 'video': 1})
#
# Watched bbno$, Yung Bae & Billy Marchiafava - Bad Boy (Official Video)
# Counter({'watched': 1, 'bbno': 1, 'yung': 1, 'bae': 1, 'billy': 1, 'marchiafava': 1, 'bad': 1, 'boy': 1, 'official': 1, 'video': 1})
#
# Watched Post Malone - Cooped Up ft. Roddy Ricch
# Counter({'watched': 1, 'post': 1, 'malone': 1, 'cooped': 1, 'ft': 1, 'roddy': 1, 'ricch': 1})
#
# Watched Glass Animals - Heat Waves (Official Video)
# Counter({'watched': 1, 'glass': 1, 'animals': 1, 'heat': 1, 'waves': 1, 'official': 1, 'video': 1})
#
# Watched I MADE MY OWN VALORANT TEAM
# Counter({'watched': 1, 'made': 1, 'valorant': 1, 'team': 1})
#
# Watched Thakarppan Comedy l Dr. Ullas and Nurse Sneha...!  l Mazhavil Manorama
# Counter({'l': 2, 'watched': 1, 'thakarppan': 1, 'comedy': 1, 'dr': 1, 'ullas': 1, 'nurse': 1, 'sneha': 1, 'mazhavil': 1, 'manorama': 1})
#
# Watched I Bought a Gaming PC from EPSON
# Counter({'watched': 1, 'bought': 1, 'gaming': 1, 'pc': 1, 'epson': 1})
#
# Watched Hamilton Beach DIGITAL RICE COOKER and FOOD STEAMER (4.75 Litre): ESSENTIAL HOME REVIEW
# Counter({'watched': 1, 'hamilton': 1, 'beach': 1, 'digital': 1, 'rice': 1, 'cooker': 1, 'food': 1, 'steamer': 1, '475': 1, 'litre': 1, 'essential': 1, 'home': 1, 'review': 1})
#
# Watched Our Portuguese Magnifico! ðŸ’« | Man Utd 1-0 Aston Villa | Highlights
# Counter({'watched': 1, 'portuguese': 1, 'magnifico': 1, 'ðÿ’«': 1, 'man': 1, 'utd': 1, '10': 1, 'aston': 1, 'villa': 1, 'highlights': 1})
#
# Watched How to Make Pancakes at Home | Easy Pancake Recipe
# Counter({'watched': 1, 'make': 1, 'pancakes': 1, 'home': 1, 'easy': 1, 'pancake': 1, 'recipe': 1})
#
# Watched How to make Pancakes | Fluffy Pancake Recipe
# Counter({'watched': 1, 'make': 1, 'pancakes': 1, 'fluffy': 1, 'pancake': 1, 'recipe': 1})
#
# Watched How To Make The Best Chicken Stir Fry | Perfect Chicken Stir Fry
# Counter({'chicken': 2, 'stir': 2, 'fry': 2, 'watched': 1, 'make': 1, 'best': 1, 'perfect': 1})
#
# Watched Easy Chicken Recipe With Bell Pepper and Onion
# Counter({'watched': 1, 'easy': 1, 'chicken': 1, 'recipe': 1, 'bell': 1, 'pepper': 1, 'onion': 1})
#
# Watched The records the British Empire didn't want you to see - Audra A. DiptÃ©e
# Counter({'watched': 1, 'records': 1, 'british': 1, 'empire': 1, 'didnt': 1, 'want': 1, 'see': 1, 'audra': 1, 'diptã©e': 1})
#
# Watched Best Way To Cook Chicken Breast l Chicken With Bell Peppers l Boneless Chicken Recipes l ì¹˜í‚¨ ë³¶ì�Œ í”¼ë§� íŠ€ê¹€
# Counter({'chicken': 3, 'l': 3, 'watched': 1, 'best': 1, 'way': 1, 'cook': 1, 'breast': 1, 'bell': 1, 'peppers': 1, 'boneless': 1, 'recipes': 1, 'ì¹˜í‚¨': 1, 'ë³¶ì�œ': 1, 'í”¼ë§�': 1, 'íš€ê¹€': 1})
#
# Watched chicken and spinach salad ðŸ¤ŒðŸ�»ðŸ¥¬
# Counter({'watched': 1, 'chicken': 1, 'spinach': 1, 'salad': 1, 'ðÿ¤œðÿ�»ðÿ¥¬': 1})
#
# Watched Easy Black Pepper Chicken Stirfry
# Counter({'watched': 1, 'easy': 1, 'black': 1, 'pepper': 1, 'chicken': 1, 'stirfry': 1})
#
# Watched I'm Embarrassed For Her...
# Counter({'watched': 1, 'im': 1, 'embarrassed': 1})
#
# Watched This $65 Idea Raised $2M on Kickstarter...
# Counter({'watched': 1, '65': 1, 'idea': 1, 'raised': 1, '2m': 1, 'kickstarter': 1})
#
# Watched The Flagship vs Midrange Debate: Galaxy A54 Review!
# Counter({'watched': 1, 'flagship': 1, 'vs': 1, 'midrange': 1, 'debate': 1, 'galaxy': 1, 'a54': 1, 'review': 1})
#
# Watched Types Of People At The Gym | Jordindian
# Counter({'watched': 1, 'types': 1, 'people': 1, 'gym': 1, 'jordindian': 1})
#
# Watched Sucker
# Counter({'watched': 1, 'sucker': 1})
#
# Watched Levitating (feat. DaBaby)
# Counter({'watched': 1, 'levitating': 1, 'feat': 1, 'dababy': 1})
#
# Watched RAJA
# Counter({'watched': 1, 'raja': 1})
#
# Watched Fire Again
# Counter({'watched': 1, 'fire': 1})
#
# Watched I Ain't Worried
# Counter({'watched': 1, 'aint': 1, 'worried': 1})
#
# Watched Entertain Me
# Counter({'watched': 1, 'entertain': 1})
#
# Watched Orch Compression
# Counter({'watched': 1, 'orch': 1, 'compression': 1})
#
# Watched Die For You ft. Grabbitz // Official Music Video // VALORANT Champions 2021
# Counter({'watched': 1, 'die': 1, 'ft': 1, 'grabbitz': 1, 'official': 1, 'music': 1, 'video': 1, 'valorant': 1, 'champions': 1, '2021': 1})
#
# Watched Fake It Til You Make It
# Counter({'watched': 1, 'fake': 1, 'til': 1, 'make': 1})
#
# Watched The Search
# Counter({'watched': 1, 'search': 1})
#
# Watched Warriors
# Counter({'watched': 1, 'warriors': 1})
#
# Watched Legends Never Die
# Counter({'watched': 1, 'legends': 1, 'never': 1, 'die': 1})
#
# Watched Way down We Go
# Counter({'watched': 1, 'way': 1, 'go': 1})
#
# Watched Heathens
# Counter({'watched': 1, 'heathens': 1})
#
# Watched Bad Boy
# Counter({'watched': 1, 'bad': 1, 'boy': 1})
#
# Watched Cake By The Ocean
# Counter({'watched': 1, 'cake': 1, 'ocean': 1})
#
# Watched No Roots
# Counter({'watched': 1, 'roots': 1})
#
# Watched Alien
# Counter({'watched': 1, 'alien': 1})
#
# Watched Stubborn Love
# Counter({'watched': 1, 'stubborn': 1, 'love': 1})
#
# Watched Cake By The Ocean
# Counter({'watched': 1, 'cake': 1, 'ocean': 1})
#
# Watched Con La Brisa
# Counter({'watched': 1, 'con': 1, 'la': 1, 'brisa': 1})
#
# Watched Pasoori
# Counter({'watched': 1, 'pasoori': 1})
#
# Watched Heat Waves
# Counter({'watched': 1, 'heat': 1, 'waves': 1})
#
# Watched The Night We Met
# Counter({'watched': 1, 'night': 1, 'met': 1})
#
# Watched Home
# Counter({'watched': 1, 'home': 1})
#
# Watched As the World Caves In
# Counter({'watched': 1, 'world': 1, 'caves': 1})
#
# Watched Everything I Need (Film Version)
# Counter({'watched': 1, 'everything': 1, 'need': 1, 'film': 1, 'version': 1})
#
# Watched I Get to Love You
# Counter({'watched': 1, 'get': 1, 'love': 1})
#
# Watched Scarborough Fair / Canticle
# Counter({'watched': 1, 'scarborough': 1, 'fair': 1, 'canticle': 1})
#
# Watched Paint
# Counter({'watched': 1, 'paint': 1})
#
# Watched Bloom (Online Bonus Track)
# Counter({'watched': 1, 'bloom': 1, 'online': 1, 'bonus': 1, 'track': 1})
#
# Watched Airplanes (feat. Hayley Williams of Paramore)
# Counter({'watched': 1, 'airplanes': 1, 'feat': 1, 'hayley': 1, 'williams': 1, 'paramore': 1})
#
# Watched Cooler Than Me (Single Mix)
# Counter({'watched': 1, 'cooler': 1, 'single': 1, 'mix': 1})
#
# Watched Stressed Out
# Counter({'watched': 1, 'stressed': 1})
#
# Watched Dissolve
# Counter({'watched': 1, 'dissolve': 1})
#
# Watched death bed (coffee for your head)
# Counter({'watched': 1, 'death': 1, 'bed': 1, 'coffee': 1, 'head': 1})
#
# Watched Hey, Soul Sister
# Counter({'watched': 1, 'hey': 1, 'soul': 1, 'sister': 1})
#
# Watched Types Of People At The Gym | Jordindian
# Counter({'watched': 1, 'types': 1, 'people': 1, 'gym': 1, 'jordindian': 1})
#
# Watched Galway Girl
# Counter({'watched': 1, 'galway': 1, 'girl': 1})
#
# Watched One Day
# Counter({'watched': 1, 'one': 1, 'day': 1})
#
# Watched The A Team
# Counter({'watched': 1, 'team': 1})
#
# Watched There's No Way
# Counter({'watched': 1, 'theres': 1, 'way': 1})
#
# Watched If the World Was Ending
# Counter({'watched': 1, 'world': 1, 'ending': 1})
#
# Watched Malibu Nights
# Counter({'watched': 1, 'malibu': 1, 'nights': 1})
#
# Watched i'm so tired...
# Counter({'watched': 1, 'im': 1, 'tired': 1})
#
# Watched Leave a Light On
# Counter({'watched': 1, 'leave': 1, 'light': 1})
#
# Watched 7 Years
# Counter({'watched': 1, '7': 1, 'years': 1})
#
# Watched Chlorine
# Counter({'watched': 1, 'chlorine': 1})
#
# Watched Sleep On The Floor
# Counter({'watched': 1, 'sleep': 1, 'floor': 1})
#
# Watched Before You Go
# Counter({'watched': 1, 'go': 1})
#
# Watched Empire State Of Mind [Jay-Z + Alicia Keys] (Explicit)
# Counter({'watched': 1, 'empire': 1, 'state': 1, 'mind': 1, 'jayz': 1, 'alicia': 1, 'keys': 1, 'explicit': 1})
#
# Watched Take Me To Church
# Counter({'watched': 1, 'take': 1, 'church': 1})
#
# Watched Underdog
# Counter({'watched': 1, 'underdog': 1})
#
# Watched Nice To Meet Ya
# Counter({'watched': 1, 'nice': 1, 'meet': 1, 'ya': 1})
#
# Watched Without Me
# Counter({'watched': 1, 'without': 1})
#
# Watched Someone You Loved
# Counter({'watched': 1, 'someone': 1, 'loved': 1})
#
# Watched Somebody That I Used To Know
# Counter({'watched': 1, 'somebody': 1, 'used': 1, 'know': 1})
#
# Watched We Set Up a Couple in 2015 & They Got MARRIED! w/ The Jonas Brothers & Norah Jones
# Counter({'watched': 1, 'set': 1, 'couple': 1, '2015': 1, 'got': 1, 'married': 1, 'w': 1, 'jonas': 1, 'brothers': 1, 'norah': 1, 'jones': 1})
#
# Watched Enkilum Chandrike Official Trailer | Suraj | Basil | Saiju | Niranjana | Adithyan | Vijay Babu | FFH
# Counter({'watched': 1, 'enkilum': 1, 'chandrike': 1, 'official': 1, 'trailer': 1, 'suraj': 1, 'basil': 1, 'saiju': 1, 'niranjana': 1, 'adithyan': 1, 'vijay': 1, 'babu': 1, 'ffh': 1})
#
# Watched Our Unreleased Products
# Counter({'watched': 1, 'unreleased': 1, 'products': 1})
#
# Watched World's Best Android Camera vs iPhone!
# Counter({'watched': 1, 'worlds': 1, 'best': 1, 'android': 1, 'camera': 1, 'vs': 1, 'iphone': 1})
#
# Watched Late Night Nightmare w/ Kimmel, Meyers, Colbert, Fallon, Letterman & Noah
# Counter({'watched': 1, 'late': 1, 'night': 1, 'nightmare': 1, 'w': 1, 'kimmel': 1, 'meyers': 1, 'colbert': 1, 'fallon': 1, 'letterman': 1, 'noah': 1})
#
# Watched Marved is here to stay
# Counter({'watched': 1, 'marved': 1, 'stay': 1})
#
# Watched Inside Hilary Duff's Family Home With A Chicken Coop | Open Door | Architectural Digest
# Counter({'watched': 1, 'inside': 1, 'hilary': 1, 'duffs': 1, 'family': 1, 'home': 1, 'chicken': 1, 'coop': 1, 'open': 1, 'door': 1, 'architectural': 1, 'digest': 1})
#
# Watched Inside Karen Gillan's Cozy California Cottage | Open Door | Architectural Digest
# Counter({'watched': 1, 'inside': 1, 'karen': 1, 'gillans': 1, 'cozy': 1, 'california': 1, 'cottage': 1, 'open': 1, 'door': 1, 'architectural': 1, 'digest': 1})
#
# Watched Inside The World's Highest Apartment | On The Market | Architectural Digest
# Counter({'watched': 1, 'inside': 1, 'worlds': 1, 'highest': 1, 'apartment': 1, 'market': 1, 'architectural': 1, 'digest': 1})
#
# Watched Inside A $75,000,000 Aspen Ski Mansion | On The Market | Architectural Digest
# Counter({'watched': 1, 'inside': 1, '75000000': 1, 'aspen': 1, 'ski': 1, 'mansion': 1, 'market': 1, 'architectural': 1, 'digest': 1})
#
# Watched Inside a Legendary $16,000,000 Canyonside Mansion | On The Market | Architectural Digest
# Counter({'watched': 1, 'inside': 1, 'legendary': 1, '16000000': 1, 'canyonside': 1, 'mansion': 1, 'market': 1, 'architectural': 1, 'digest': 1})
#
# Watched Inside An Iconic $21,000,000 Mansion Once Owned By Madonna | On The Market | Architectural Digest
# Counter({'watched': 1, 'inside': 1, 'iconic': 1, '21000000': 1, 'mansion': 1, 'owned': 1, 'madonna': 1, 'market': 1, 'architectural': 1, 'digest': 1})
#
# Watched YouTube Made Me Review This Budget GPU - GT 1030
# Counter({'watched': 1, 'youtube': 1, 'made': 1, 'review': 1, 'budget': 1, 'gpu': 1, 'gt': 1, '1030': 1})
#
# Watched GAME ON // Episode 6: Act III Kickoff - VALORANT
# Counter({'watched': 1, 'game': 1, 'episode': 1, '6': 1, 'act': 1, 'iii': 1, 'kickoff': 1, 'valorant': 1})
#
# Watched How 'Modern Warfare II' Became The Most Realistic 'Call Of Duty' Game | Movies Insider | Insider
# Counter({'insider': 2, 'watched': 1, 'modern': 1, 'warfare': 1, 'ii': 1, 'became': 1, 'realistic': 1, 'call': 1, 'duty': 1, 'game': 1, 'movies': 1})
#
# Watched MKBHD Didn't Expect This...
# Counter({'watched': 1, 'mkbhd': 1, 'didnt': 1, 'expect': 1})
#
# Watched LOUD Aspas Avoided The Neon Stun by Jumping
# Counter({'watched': 1, 'loud': 1, 'aspas': 1, 'avoided': 1, 'neon': 1, 'stun': 1, 'jumping': 1})
#
# Watched What Makes Something See-Through? | Neil deGrasse Tyson Explains...
# Counter({'watched': 1, 'makes': 1, 'something': 1, 'seethrough': 1, 'neil': 1, 'degrasse': 1, 'tyson': 1, 'explains': 1})
#
# Watched TANF: Last Week Tonight with John Oliver (HBO)
# Counter({'watched': 1, 'tanf': 1, 'last': 1, 'week': 1, 'tonight': 1, 'john': 1, 'oliver': 1, 'hbo': 1})
#
# Watched Dear MKBHD
# Counter({'watched': 1, 'dear': 1, 'mkbhd': 1})
#
# Watched I Made My Own Sneaker! M251
# Counter({'watched': 1, 'made': 1, 'sneaker': 1, 'm251': 1})
#
# Watched Honest Trailers | Ant-Man and the Wasp: Quantumania
# Counter({'watched': 1, 'honest': 1, 'trailers': 1, 'antman': 1, 'wasp': 1, 'quantumania': 1})
#
# Watched KAI ETHUM DOORATHU | ROAST E33 | Fahadh Fazil | Nikita | Malayalam Movie Funny Review | OUTSPOKEN
# Counter({'watched': 1, 'kai': 1, 'ethum': 1, 'doorathu': 1, 'roast': 1, 'e33': 1, 'fahadh': 1, 'fazil': 1, 'nikita': 1, 'malayalam': 1, 'movie': 1, 'funny': 1, 'review': 1, 'outspoken': 1})
#
# Watched RAHUL SUBRAMANIAN | CROWD WORK | THE COIN DROP MYSTERY
# Counter({'watched': 1, 'rahul': 1, 'subramanian': 1, 'crowd': 1, 'work': 1, 'coin': 1, 'drop': 1, 'mystery': 1})
#
# Watched Stand Up Comedy - Crowd Work  | Kenny Sebastian - Best & Worst Memories : Deep Sea Diving
# Counter({'watched': 1, 'stand': 1, 'comedy': 1, 'crowd': 1, 'work': 1, 'kenny': 1, 'sebastian': 1, 'best': 1, 'worst': 1, 'memories': 1, 'deep': 1, 'sea': 1, 'diving': 1})
#
# Watched The Jonas Brothers Dish on The Album and Accidentally Predicting the Future in "Year 3000"
# Counter({'watched': 1, 'jonas': 1, 'brothers': 1, 'dish': 1, 'album': 1, 'accidentally': 1, 'predicting': 1, 'future': 1, 'year': 1, '3000': 1})
#
# Watched Timeshares: Last Week Tonight with John Oliver (HBO)
# Counter({'watched': 1, 'timeshares': 1, 'last': 1, 'week': 1, 'tonight': 1, 'john': 1, 'oliver': 1, 'hbo': 1})
#
# Watched ICEMAN PENALTY SENDS US TO THE FINAL ðŸ¥¶ | Brighton (6) 0-0 (7) United | Highlights
# Counter({'watched': 1, 'iceman': 1, 'penalty': 1, 'sends': 1, 'us': 1, 'final': 1, 'ðÿ¥¶': 1, 'brighton': 1, '6': 1, '00': 1, '7': 1, 'united': 1, 'highlights': 1})
#
# Watched Who Will Win? ðŸ¤” | Old Trafford x Emirates Stadium | MCR vs LDN
# Counter({'watched': 1, 'win': 1, 'ðÿ¤”': 1, 'old': 1, 'trafford': 1, 'x': 1, 'emirates': 1, 'stadium': 1, 'mcr': 1, 'vs': 1, 'ldn': 1})
#
# Watched How to Integrate ChatGPT in Jupyter Notebooks for Free!
# Counter({'watched': 1, 'integrate': 1, 'chatgpt': 1, 'jupyter': 1, 'notebooks': 1, 'free': 1})
#
# Watched What's It Like to Work For Linus? - YouTuber Employees Answer 2023
# Counter({'watched': 1, 'whats': 1, 'like': 1, 'work': 1, 'linus': 1, 'youtuber': 1, 'employees': 1, 'answer': 1, '2023': 1})
#
# Watched Forgotten Malayalam Movies S03 E06 | Udhayam | Jithu | Nandini | Malayalam Movie Review Funny
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's03': 1, 'e06': 1, 'udhayam': 1, 'jithu': 1, 'nandini': 1, 'movie': 1, 'review': 1, 'funny': 1})
#
# Watched You donâ€™t need a new PC
# Counter({'watched': 1, 'donâ€™t': 1, 'need': 1, 'new': 1, 'pc': 1})
#
# Watched I Spent $40,000 to Unbox a Sealed Original iPhone!
# Counter({'watched': 1, 'spent': 1, '40000': 1, 'unbox': 1, 'sealed': 1, 'original': 1, 'iphone': 1})
#
# Watched DOSA TIER LIST | Stream Highlights (+ taylor swift albums)
# Counter({'watched': 1, 'dosa': 1, 'tier': 1, 'list': 1, 'stream': 1, 'highlights': 1, 'taylor': 1, 'swift': 1, 'albums': 1})
#
# Watched Indian Chinese | Varun Thakur | Stand Up Comedy
# Counter({'watched': 1, 'indian': 1, 'chinese': 1, 'varun': 1, 'thakur': 1, 'stand': 1, 'comedy': 1})
#
# Watched Best of Chandler Jokes | Friends
# Counter({'watched': 1, 'best': 1, 'chandler': 1, 'jokes': 1, 'friends': 1})
#
# Watched Wrexham Gets Promoted
# Counter({'watched': 1, 'wrexham': 1, 'gets': 1, 'promoted': 1})
#
# Watched Howâ€™d we get an arcade full of inspiration into one skin? The Radiant Entertainment System.
# Counter({'watched': 1, 'howâ€™d': 1, 'get': 1, 'arcade': 1, 'full': 1, 'inspiration': 1, 'one': 1, 'skin': 1, 'radiant': 1, 'entertainment': 1, 'system': 1})
#
# Watched Uncle Roger MAKE EGG FRIED RICE (3M Subscriber Special!)
# Counter({'watched': 1, 'uncle': 1, 'roger': 1, 'make': 1, 'egg': 1, 'fried': 1, 'rice': 1, '3m': 1, 'subscriber': 1, 'special': 1})
#
# Watched LEO - Bloody Sweet Promo | Thalapathy Vijay | Lokesh Kanagaraj | Anirudh
# Counter({'watched': 1, 'leo': 1, 'bloody': 1, 'sweet': 1, 'promo': 1, 'thalapathy': 1, 'vijay': 1, 'lokesh': 1, 'kanagaraj': 1, 'anirudh': 1})
#
# Watched RIZZ REVIEW ft. @Theabishekkumar | Stream Highlights
# Counter({'watched': 1, 'rizz': 1, 'review': 1, 'ft': 1, 'theabishekkumar': 1, 'stream': 1, 'highlights': 1})
#
# Watched 2018 - Official Trailer | Tovino Thomas | Jude Anthany Joseph | Kavya Film Company | Nobin Paul
# Counter({'watched': 1, '2018': 1, 'official': 1, 'trailer': 1, 'tovino': 1, 'thomas': 1, 'jude': 1, 'anthany': 1, 'joseph': 1, 'kavya': 1, 'film': 1, 'company': 1, 'nobin': 1, 'paul': 1})
#
# Watched Jackie Chan & Steve Canâ€™t Understand Each Other
# Counter({'watched': 1, 'jackie': 1, 'chan': 1, 'steve': 1, 'canâ€™t': 1, 'understand': 1})
#
# Watched GORDON RAMSAY CALL OUT UNCLE ROGER!
# Counter({'watched': 1, 'gordon': 1, 'ramsay': 1, 'call': 1, 'uncle': 1, 'roger': 1})
#
# Watched Once Upon a Time
# Counter({'watched': 1, 'upon': 1, 'time': 1})
#
# Watched Porkanda Singam
# Counter({'watched': 1, 'porkanda': 1, 'singam': 1})
#
# Watched Vikram (Title Track)
# Counter({'watched': 1, 'vikram': 1, 'title': 1, 'track': 1})
#
# Watched Levitating
# Counter({'watched': 1, 'levitating': 1})
#
# Watched Way down We Go
# Counter({'watched': 1, 'way': 1, 'go': 1})
#
# Watched LindelÃ¶f Sets Up All Manchester Final | Brighton 0-0 (6-7) Manchester United | Emirates FA Cup 22-23
# Counter({'manchester': 2, 'watched': 1, 'lindelã¶f': 1, 'sets': 1, 'final': 1, 'brighton': 1, '00': 1, '67': 1, 'united': 1, 'emirates': 1, 'fa': 1, 'cup': 1, '2223': 1})
#
# Watched Con La Brisa
# Counter({'watched': 1, 'con': 1, 'la': 1, 'brisa': 1})
#
# Watched Pasoori
# Counter({'watched': 1, 'pasoori': 1})
#
# Watched Heat Waves
# Counter({'watched': 1, 'heat': 1, 'waves': 1})
#
# Watched HandClap
# Counter({'watched': 1, 'handclap': 1})
#
# Watched Levitating (feat. DaBaby)
# Counter({'watched': 1, 'levitating': 1, 'feat': 1, 'dababy': 1})
#
# Watched Sucker
# Counter({'watched': 1, 'sucker': 1})
#
# Watched RAJA
# Counter({'watched': 1, 'raja': 1})
#
# Watched Fire Again
# Counter({'watched': 1, 'fire': 1})
#
# Watched I Ain't Worried
# Counter({'watched': 1, 'aint': 1, 'worried': 1})
#
# Watched Entertain Me
# Counter({'watched': 1, 'entertain': 1})
#
# Watched Orch Compression
# Counter({'watched': 1, 'orch': 1, 'compression': 1})
#
# Watched Die For You ft. Grabbitz // Official Music Video // VALORANT Champions 2021
# Counter({'watched': 1, 'die': 1, 'ft': 1, 'grabbitz': 1, 'official': 1, 'music': 1, 'video': 1, 'valorant': 1, 'champions': 1, '2021': 1})
#
# Watched Fake It Til You Make It
# Counter({'watched': 1, 'fake': 1, 'til': 1, 'make': 1})
#
# Watched The Search
# Counter({'watched': 1, 'search': 1})
#
# Watched Warriors
# Counter({'watched': 1, 'warriors': 1})
#
# Watched Legends Never Die
# Counter({'watched': 1, 'legends': 1, 'never': 1, 'die': 1})
#
# Watched Uncle Roger Work at Bubble Tea Shop
# Counter({'watched': 1, 'uncle': 1, 'roger': 1, 'work': 1, 'bubble': 1, 'tea': 1, 'shop': 1})
#
# Watched Uncle Roger Work at Food Truck
# Counter({'watched': 1, 'uncle': 1, 'roger': 1, 'work': 1, 'food': 1, 'truck': 1})
#
# Watched I bought every MacBook Ever.
# Counter({'watched': 1, 'bought': 1, 'every': 1, 'macbook': 1, 'ever': 1})
#
# Watched PRESS PLAY  // Radiant Entertainment System Skin Trailer - VALORANT
# Counter({'watched': 1, 'press': 1, 'play': 1, 'radiant': 1, 'entertainment': 1, 'system': 1, 'skin': 1, 'trailer': 1, 'valorant': 1})
#
# Watched Honest Trailers | Shazam! Fury of the Gods
# Counter({'watched': 1, 'honest': 1, 'trailers': 1, 'shazam': 1, 'fury': 1, 'gods': 1})
#
# Watched Forgotten Malayalam Movies S03 E07 | Veerasamy | Malayalam Movie Review Funny | T.Rajender
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's03': 1, 'e07': 1, 'veerasamy': 1, 'movie': 1, 'review': 1, 'funny': 1, 'trajender': 1})
#
# Watched Forgotten Malayalam Movies S02 E11 |Rain Rain Come Again |Malayalam Movie Review Funny|Season Finale
# Counter({'malayalam': 2, 'rain': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's02': 1, 'e11': 1, 'come': 1, 'movie': 1, 'review': 1, 'funnyseason': 1, 'finale': 1})
#
# Watched Forgotten Malayalam Movies S04 E02 | The Warrant | Malayalam Movie Review Funny | Napolean
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's04': 1, 'e02': 1, 'warrant': 1, 'movie': 1, 'review': 1, 'funny': 1, 'napolean': 1})
#
# Watched Meri Inter Caste Marriage | Stand Up Comedy | Pratyush Chaubey
# Counter({'watched': 1, 'meri': 1, 'inter': 1, 'caste': 1, 'marriage': 1, 'stand': 1, 'comedy': 1, 'pratyush': 1, 'chaubey': 1})
#
# Watched RIZZ REVIEW ft. @Theabishekkumar | Stream Highlights
# Counter({'watched': 1, 'rizz': 1, 'review': 1, 'ft': 1, 'theabishekkumar': 1, 'stream': 1, 'highlights': 1})
#
# Watched Googleâ€™s BI vs. Advanced Data Analytics Certificates
# Counter({'watched': 1, 'googleâ€™s': 1, 'bi': 1, 'vs': 1, 'advanced': 1, 'data': 1, 'analytics': 1, 'certificates': 1})
#
# Watched Americans React to Kerala Food (Malayali) | Porotta & Beef, Pazham Pori, Egg Puffs, Payasam
# Counter({'watched': 1, 'americans': 1, 'react': 1, 'kerala': 1, 'food': 1, 'malayali': 1, 'porotta': 1, 'beef': 1, 'pazham': 1, 'pori': 1, 'egg': 1, 'puffs': 1, 'payasam': 1})
#
# Watched Weird Histories of Indian Monuments | Parotta Act
# Counter({'watched': 1, 'weird': 1, 'histories': 1, 'indian': 1, 'monuments': 1, 'parotta': 1, 'act': 1})
#
# Watched Why India Drinks So Much Chai | Parotta Act
# Counter({'watched': 1, 'india': 1, 'drinks': 1, 'much': 1, 'chai': 1, 'parotta': 1, 'act': 1})
#
# Watched Forgotten Malayalam Movies S03 E08 | Abraham and Lincoln | Malayalam Movie Review Funny | Rahman
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's03': 1, 'e08': 1, 'abraham': 1, 'lincoln': 1, 'movie': 1, 'review': 1, 'funny': 1, 'rahman': 1})
#
# Watched Forgotten Malayalam Movies S03 E10 | Keralotsavam 2009 | Malayalam Movie Review Funny | Vinu Mohan
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's03': 1, 'e10': 1, 'keralotsavam': 1, '2009': 1, 'movie': 1, 'review': 1, 'funny': 1, 'vinu': 1, 'mohan': 1})
#
# Watched How to buy a Used Car in Canada? | Complete Guide | à¤¹à¤¿à¤‚à¤¦à¥€ à¤®à¥‡à¤‚
# Counter({'watched': 1, 'buy': 1, 'used': 1, 'car': 1, 'canada': 1, 'complete': 1, 'guide': 1, 'à¤¹à¤¿à¤‚à¤¦à¥€': 1, 'à¤®à¥‡à¤‚': 1})
#
# Watched Types Of Cars In Canada | Car Buying Tips In Canada | Canada Couple
# Counter({'canada': 3, 'watched': 1, 'types': 1, 'cars': 1, 'car': 1, 'buying': 1, 'tips': 1, 'couple': 1})
#
# Watched Car Prices Are DROPPING And THIS Is When You Should Buy A Car In 2023
# Counter({'car': 2, 'watched': 1, 'prices': 1, 'dropping': 1, 'buy': 1, '2023': 1})
#
# Watched BOUGHT MY FIRST CAR IN CANADA| How to buy a Used Car in Canada?| Complete Guide| Things to consider?
# Counter({'car': 2, 'canada': 2, 'watched': 1, 'bought': 1, 'first': 1, 'buy': 1, 'used': 1, 'complete': 1, 'guide': 1, 'things': 1, 'consider': 1})
#
# Watched Saved $2,000 on our CAR ðŸ¤‘ |  The ultimate guide to buying a car in Canada ðŸš—ðŸ‡¨ðŸ‡¦
# Counter({'car': 2, 'watched': 1, 'saved': 1, '2000': 1, 'ðÿ¤‘': 1, 'ultimate': 1, 'guide': 1, 'buying': 1, 'canada': 1, 'ðÿš—ðÿ‡¨ðÿ‡¦': 1})
#
# Watched 96 Songs | The Life of Ram Video Song | Vijay Sethupathi, Trisha | Govind Vasantha | C. Prem Kumar
# Counter({'watched': 1, '96': 1, 'songs': 1, 'life': 1, 'ram': 1, 'video': 1, 'song': 1, 'vijay': 1, 'sethupathi': 1, 'trisha': 1, 'govind': 1, 'vasantha': 1, 'c': 1, 'prem': 1, 'kumar': 1})
#
# Watched Don - Jalabulajangu Video | Sivakarthikeyan | Anirudh Ravichander
# Counter({'watched': 1, 'jalabulajangu': 1, 'video': 1, 'sivakarthikeyan': 1, 'anirudh': 1, 'ravichander': 1})
#
# Watched Mankatha - Balle Lakka Video | Ajith, Trisha | Yuvan
# Counter({'watched': 1, 'mankatha': 1, 'balle': 1, 'lakka': 1, 'video': 1, 'ajith': 1, 'trisha': 1, 'yuvan': 1})
#
# Watched Balleilakka Song HD [1080p] - Sivaji The Boss
# Counter({'watched': 1, 'balleilakka': 1, 'song': 1, 'hd': 1, '1080p': 1, 'sivaji': 1, 'boss': 1})
#
# Watched Kaathuvaakula Rendu Kaadhal - Dippam Dappam Video | Vijay Sethupathi, Anirudh
# Counter({'watched': 1, 'kaathuvaakula': 1, 'rendu': 1, 'kaadhal': 1, 'dippam': 1, 'dappam': 1, 'video': 1, 'vijay': 1, 'sethupathi': 1, 'anirudh': 1})
#
# Watched Jennifer Lopez - On The Floor ft. Pitbull
# Counter({'watched': 1, 'jennifer': 1, 'lopez': 1, 'floor': 1, 'ft': 1, 'pitbull': 1})
#
# Watched Maari 2 - Rowdy Baby (Video Song) | Dhanush, Sai Pallavi | Yuvan Shankar Raja | Balaji Mohan
# Counter({'watched': 1, 'maari': 1, '2': 1, 'rowdy': 1, 'baby': 1, 'video': 1, 'song': 1, 'dhanush': 1, 'sai': 1, 'pallavi': 1, 'yuvan': 1, 'shankar': 1, 'raja': 1, 'balaji': 1, 'mohan': 1})
#
# Watched Maari - Donâ€™u Donâ€™u Donâ€™u Video | Dhanush, Kajal | Anirudh | Super Hit Song
# Counter({'donâ€™u': 3, 'watched': 1, 'maari': 1, 'video': 1, 'dhanush': 1, 'kajal': 1, 'anirudh': 1, 'super': 1, 'hit': 1, 'song': 1})
#
# Watched Maari - Maari Thara Local Video | Dhanush | Anirudh Ravichander
# Counter({'maari': 2, 'watched': 1, 'thara': 1, 'local': 1, 'video': 1, 'dhanush': 1, 'anirudh': 1, 'ravichander': 1})
#
# Watched VIKRAM - Porkanda Singam EDM Video | Kamal Haasan | Vijay Sethupathi | Lokesh Kanagaraj | Anirudh
# Counter({'watched': 1, 'vikram': 1, 'porkanda': 1, 'singam': 1, 'edm': 1, 'video': 1, 'kamal': 1, 'haasan': 1, 'vijay': 1, 'sethupathi': 1, 'lokesh': 1, 'kanagaraj': 1, 'anirudh': 1})
#
# Watched Once Upon A Time Video | VIKRAM | Kamal Haasan | Anirudh Ravichander | Lokesh Kanagaraj
# Counter({'watched': 1, 'upon': 1, 'time': 1, 'video': 1, 'vikram': 1, 'kamal': 1, 'haasan': 1, 'anirudh': 1, 'ravichander': 1, 'lokesh': 1, 'kanagaraj': 1})
#
# Watched VIKRAM Title Track Lyric | Kamal Haasan | Vijay Sethupathi | Lokesh Kanagaraj | Anirudh
# Counter({'watched': 1, 'vikram': 1, 'title': 1, 'track': 1, 'lyric': 1, 'kamal': 1, 'haasan': 1, 'vijay': 1, 'sethupathi': 1, 'lokesh': 1, 'kanagaraj': 1, 'anirudh': 1})
#
# Watched Pushpa: Saami Saami - Full Video Song | Allu Arjun, Rashmika Mandanna | Sunidhi C | DSP | Sukumar
# Counter({'saami': 2, 'watched': 1, 'pushpa': 1, 'full': 1, 'video': 1, 'song': 1, 'allu': 1, 'arjun': 1, 'rashmika': 1, 'mandanna': 1, 'sunidhi': 1, 'c': 1, 'dsp': 1, 'sukumar': 1})
#
# Watched Manavaalan Thug - Thallumaala Promo Song | Tovino Thomas | Khalid Rahman| Ashiq Usman |Suhail Backer
# Counter({'watched': 1, 'manavaalan': 1, 'thug': 1, 'thallumaala': 1, 'promo': 1, 'song': 1, 'tovino': 1, 'thomas': 1, 'khalid': 1, 'rahman': 1, 'ashiq': 1, 'usman': 1, 'suhail': 1, 'backer': 1})
#
# Watched Athmave Po - Lyrical | Romancham | Sushin Shyam | Johnpaul George Productions | Jithu Madhavan
# Counter({'watched': 1, 'athmave': 1, 'po': 1, 'lyrical': 1, 'romancham': 1, 'sushin': 1, 'shyam': 1, 'johnpaul': 1, 'george': 1, 'productions': 1, 'jithu': 1, 'madhavan': 1})
#
# Watched Pala Palli Thiruppalli Promo Song | Kaduva | Jakes Bejoy | Shaji Kailas | Prithviraj Sukumaran
# Counter({'watched': 1, 'pala': 1, 'palli': 1, 'thiruppalli': 1, 'promo': 1, 'song': 1, 'kaduva': 1, 'jakes': 1, 'bejoy': 1, 'shaji': 1, 'kailas': 1, 'prithviraj': 1, 'sukumaran': 1})
#
# Watched Aadharanjali - Promo Song | Romancham | Sushin Shyam | Johnpaul George Productions | Jithu Madhavan
# Counter({'watched': 1, 'aadharanjali': 1, 'promo': 1, 'song': 1, 'romancham': 1, 'sushin': 1, 'shyam': 1, 'johnpaul': 1, 'george': 1, 'productions': 1, 'jithu': 1, 'madhavan': 1})
#
# Watched Romancham - Title Track | Sushin Shyam| Johnpaul George Productions| Jithu Madhavan
# Counter({'watched': 1, 'romancham': 1, 'title': 1, 'track': 1, 'sushin': 1, 'shyam': 1, 'johnpaul': 1, 'george': 1, 'productions': 1, 'jithu': 1, 'madhavan': 1})
#
# Watched Thalatherichavar - Video | Romancham | Sushin Shyam | Johnpaul George Productions | Jithu Madhavan
# Counter({'watched': 1, 'thalatherichavar': 1, 'video': 1, 'romancham': 1, 'sushin': 1, 'shyam': 1, 'johnpaul': 1, 'george': 1, 'productions': 1, 'jithu': 1, 'madhavan': 1})
#
# Watched Jimikki Kammal  | Velipadinte Pusthakam
# Counter({'watched': 1, 'jimikki': 1, 'kammal': 1, 'velipadinte': 1, 'pusthakam': 1})
#
# Watched Villu | Daddy Mummy - Video Song | Vijay | Prabhudeva | Devi Sri Prasad | Ayngaran
# Counter({'watched': 1, 'villu': 1, 'daddy': 1, 'mummy': 1, 'video': 1, 'song': 1, 'vijay': 1, 'prabhudeva': 1, 'devi': 1, 'sri': 1, 'prasad': 1, 'ayngaran': 1})
#
# Watched Kalippu | Premam
# Counter({'watched': 1, 'kalippu': 1, 'premam': 1})
#
# Watched Pista The Run Anthem - Video Song | Neram | Nivin Pauly | Nazriya Nazim | Alphonse Puthren
# Counter({'watched': 1, 'pista': 1, 'run': 1, 'anthem': 1, 'video': 1, 'song': 1, 'neram': 1, 'nivin': 1, 'pauly': 1, 'nazriya': 1, 'nazim': 1, 'alphonse': 1, 'puthren': 1})
#
# Watched Brodha V x Jordindian - Vainko [Music Video]
# Counter({'watched': 1, 'brodha': 1, 'v': 1, 'x': 1, 'jordindian': 1, 'vainko': 1, 'music': 1, 'video': 1})
#
# Watched Basti Bounce - Brodha V ft. @Jordindian | Official Music Video
# Counter({'watched': 1, 'basti': 1, 'bounce': 1, 'brodha': 1, 'v': 1, 'ft': 1, 'jordindian': 1, 'official': 1, 'music': 1, 'video': 1})
#
# Watched Darshana - Official Video Song | Hridayam | Pranav | Darshana | Vineeth | Hesham | Merryland
# Counter({'darshana': 2, 'watched': 1, 'official': 1, 'video': 1, 'song': 1, 'hridayam': 1, 'pranav': 1, 'vineeth': 1, 'hesham': 1, 'merryland': 1})
#
# Watched Vikram Title Track - Film Version | Kamal Haasan, Vijay | Anirudh, Siddharth Mahadevan
# Counter({'watched': 1, 'vikram': 1, 'title': 1, 'track': 1, 'film': 1, 'version': 1, 'kamal': 1, 'haasan': 1, 'vijay': 1, 'anirudh': 1, 'siddharth': 1, 'mahadevan': 1})
#
# Watched Pathala Pathala Video | VIKRAM | Kamal Haasan | Anirudh Ravichander | Lokesh Kanagaraj
# Counter({'pathala': 2, 'watched': 1, 'video': 1, 'vikram': 1, 'kamal': 1, 'haasan': 1, 'anirudh': 1, 'ravichander': 1, 'lokesh': 1, 'kanagaraj': 1})
#
# Watched Honest Trailers | Avatar: The Way of Water
# Counter({'watched': 1, 'honest': 1, 'trailers': 1, 'avatar': 1, 'way': 1, 'water': 1})
#
# Watched Fire Again
# Counter({'watched': 1, 'fire': 1})
#
# Watched I Ain't Worried
# Counter({'watched': 1, 'aint': 1, 'worried': 1})
#
# Watched Entertain Me
# Counter({'watched': 1, 'entertain': 1})
#
# Watched Orch Compression
# Counter({'watched': 1, 'orch': 1, 'compression': 1})
#
# Watched Die For You ft. Grabbitz // Official Music Video // VALORANT Champions 2021
# Counter({'watched': 1, 'die': 1, 'ft': 1, 'grabbitz': 1, 'official': 1, 'music': 1, 'video': 1, 'valorant': 1, 'champions': 1, '2021': 1})
#
# Watched Fake It Til You Make It
# Counter({'watched': 1, 'fake': 1, 'til': 1, 'make': 1})
#
# Watched Honest Trailers | Avatar: The Way of Water
# Counter({'watched': 1, 'honest': 1, 'trailers': 1, 'avatar': 1, 'way': 1, 'water': 1})
#
# Watched Marvel Studiosâ€™ The Marvels | Teaser Trailer
# Counter({'watched': 1, 'marvel': 1, 'studiosâ€™': 1, 'marvels': 1, 'teaser': 1, 'trailer': 1})
#
# Watched HISTORY IS A LIE | Azeem Banatwalla Stand-Up Comedy (2023)
# Counter({'watched': 1, 'history': 1, 'lie': 1, 'azeem': 1, 'banatwalla': 1, 'standup': 1, 'comedy': 1, '2023': 1})
#
# Watched Our roster is changing
# Counter({'watched': 1, 'roster': 1, 'changing': 1})
#
# Watched SHROUD VS GUY W/ 10,000 HOURS OF COUNTER STRIKE
# Counter({'watched': 1, 'shroud': 1, 'vs': 1, 'guy': 1, 'w': 1, '10000': 1, 'hours': 1, 'counter': 1, 'strike': 1})
#
# Watched Global Open Beta: How to Play // Premier - VALORANT
# Counter({'watched': 1, 'global': 1, 'open': 1, 'beta': 1, 'play': 1, 'premier': 1, 'valorant': 1})
#
# Watched MOST ACTING EVER -Main Prem Ki Diwani Hoon Review
# Counter({'watched': 1, 'acting': 1, 'ever': 1, 'main': 1, 'prem': 1, 'ki': 1, 'diwani': 1, 'hoon': 1, 'review': 1})
#
# Watched Forgotten Malayalam Movies S03 E03 | The Thriller |  Appuppan face reveal | Malayalam Movie Review
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's03': 1, 'e03': 1, 'thriller': 1, 'appuppan': 1, 'face': 1, 'reveal': 1, 'movie': 1, 'review': 1})
#
# Watched Forgotten Malayalam Movies S03 E02 | Goa | Malayalam Movie Review Funny | Devan | Madhupal
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's03': 1, 'e02': 1, 'goa': 1, 'movie': 1, 'review': 1, 'funny': 1, 'devan': 1, 'madhupal': 1})
#
# Watched Forgotten Malayalam Movies S02 E07 | Chintamani Kolacase | Malayalam Movie Review Funny | SureshGopi
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's02': 1, 'e07': 1, 'chintamani': 1, 'kolacase': 1, 'movie': 1, 'review': 1, 'funny': 1, 'sureshgopi': 1})
#
# Watched Forgotten Malayalam Movies S02 E06 | Jayam | Malayalam Movie Review Funny | Nandan | Vinayakan
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's02': 1, 'e06': 1, 'jayam': 1, 'movie': 1, 'review': 1, 'funny': 1, 'nandan': 1, 'vinayakan': 1})
#
# Watched Forgotten Malayalam Movies S02 E05 | Narakasuran | Malayalam Movie Review Funny | Riyas Khan | Devan
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's02': 1, 'e05': 1, 'narakasuran': 1, 'movie': 1, 'review': 1, 'funny': 1, 'riyas': 1, 'khan': 1, 'devan': 1})
#
# Watched Forgotten Malayalam Movies S02 E04 | Chaverpada | Malayalam Movie Review Funny | Manikuttan | Bala
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's02': 1, 'e04': 1, 'chaverpada': 1, 'movie': 1, 'review': 1, 'funny': 1, 'manikuttan': 1, 'bala': 1})
#
# Watched Forgotten Malayalam Movies S02 E03 | Bhadra | Malayalam Movie Review Funny | Shankar | Jagadeesh
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's02': 1, 'e03': 1, 'bhadra': 1, 'movie': 1, 'review': 1, 'funny': 1, 'shankar': 1, 'jagadeesh': 1})
#
# Watched Forgotten Malayalam Movies S02 E02 | Vaidooryam | Malayalam Movie Review Funny | Kailash
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's02': 1, 'e02': 1, 'vaidooryam': 1, 'movie': 1, 'review': 1, 'funny': 1, 'kailash': 1})
#
# Watched Forgotten Malayalam Movies S02 E01 : Black Stallion | Malayalam Movie Review Funny | Kalabhavan Mani
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's02': 1, 'e01': 1, 'black': 1, 'stallion': 1, 'movie': 1, 'review': 1, 'funny': 1, 'kalabhavan': 1, 'mani': 1})
#
# Watched Forgotten Malayalam Movies S03 E09 | Brahmarakshas | Malayalam Movie Review Funny | Devan
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's03': 1, 'e09': 1, 'brahmarakshas': 1, 'movie': 1, 'review': 1, 'funny': 1, 'devan': 1})
#
# Watched Forgotten Malayalam Movies S02 E09 | Soudamini | Malayalam Movie Review Funny | Captain Raju
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's02': 1, 'e09': 1, 'soudamini': 1, 'movie': 1, 'review': 1, 'funny': 1, 'captain': 1, 'raju': 1})
#
# Watched Forgotten Malayalam Movies S03 E04 | Entry | Malayalam Movie Review Funny | Ranjini Haridas | Bhagat
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's03': 1, 'e04': 1, 'entry': 1, 'movie': 1, 'review': 1, 'funny': 1, 'ranjini': 1, 'haridas': 1, 'bhagat': 1})
#
# Watched Die For You ft. Grabbitz // Official Music Video // VALORANT Champions 2021
# Counter({'watched': 1, 'die': 1, 'ft': 1, 'grabbitz': 1, 'official': 1, 'music': 1, 'video': 1, 'valorant': 1, 'champions': 1, '2021': 1})
#
# Watched Fake It Til You Make It
# Counter({'watched': 1, 'fake': 1, 'til': 1, 'make': 1})
#
# Watched The Search
# Counter({'watched': 1, 'search': 1})
#
# Watched Warriors
# Counter({'watched': 1, 'warriors': 1})
#
# Watched Legends Never Die
# Counter({'watched': 1, 'legends': 1, 'never': 1, 'die': 1})
#
# Watched Way down We Go
# Counter({'watched': 1, 'way': 1, 'go': 1})
#
# Watched Heathens
# Counter({'watched': 1, 'heathens': 1})
#
# Watched Bad Boy
# Counter({'watched': 1, 'bad': 1, 'boy': 1})
#
# Watched Cake By The Ocean
# Counter({'watched': 1, 'cake': 1, 'ocean': 1})
#
# Watched No Roots
# Counter({'watched': 1, 'roots': 1})
#
# Watched Alien
# Counter({'watched': 1, 'alien': 1})
#
# Watched Fire Again
# Counter({'watched': 1, 'fire': 1})
#
# Watched Con La Brisa
# Counter({'watched': 1, 'con': 1, 'la': 1, 'brisa': 1})
#
# Watched Pasoori
# Counter({'watched': 1, 'pasoori': 1})
#
# Watched Heat Waves
# Counter({'watched': 1, 'heat': 1, 'waves': 1})
#
# Watched The Night We Met
# Counter({'watched': 1, 'night': 1, 'met': 1})
#
# Watched Home
# Counter({'watched': 1, 'home': 1})
#
# Watched As the World Caves In
# Counter({'watched': 1, 'world': 1, 'caves': 1})
#
# Watched Everything I Need (Film Version)
# Counter({'watched': 1, 'everything': 1, 'need': 1, 'film': 1, 'version': 1})
#
# Watched How Mythology Influenced the Constellations | Neil deGrasse Tyson Explainsâ€¦
# Counter({'watched': 1, 'mythology': 1, 'influenced': 1, 'constellations': 1, 'neil': 1, 'degrasse': 1, 'tyson': 1, 'explainsâ€¦': 1})
#
# Watched HOW I GOT A WORLD RECORD IN COUNTER STRIKE 2
# Counter({'watched': 1, 'got': 1, 'world': 1, 'record': 1, 'counter': 1, 'strike': 1, '2': 1})
#
# Watched How it sounds to get á¶ **áµ�áµ‰áµˆ up by NRG
# Counter({'watched': 1, 'sounds': 1, 'get': 1, 'á¶': 1, 'áµ�áµ‰áµˆ': 1, 'nrg': 1})
#
# Watched STOP Buying ANDROID TV Boxes!
# Counter({'watched': 1, 'stop': 1, 'buying': 1, 'android': 1, 'tv': 1, 'boxes': 1})
#
# Watched Jake Gyllenhaal Gets a Leg Cramp While Eating Spicy Wings | Hot Ones
# Counter({'watched': 1, 'jake': 1, 'gyllenhaal': 1, 'gets': 1, 'leg': 1, 'cramp': 1, 'eating': 1, 'spicy': 1, 'wings': 1, 'hot': 1, 'ones': 1})
#
# Watched Fastest Android EVER vs iPhone!
# Counter({'watched': 1, 'fastest': 1, 'android': 1, 'ever': 1, 'vs': 1, 'iphone': 1})
#
# Watched The ROG Phone 7 Ultimate is Just Ridiculous!
# Counter({'watched': 1, 'rog': 1, 'phone': 1, '7': 1, 'ultimate': 1, 'ridiculous': 1})
#
# Watched Iâ€™m Dreading this Review â€“ RTX 4070
# Counter({'watched': 1, 'iâ€™m': 1, 'dreading': 1, 'review': 1, 'â€“': 1, 'rtx': 1, '4070': 1})
#
# Watched How to get US Visa as a student in Canada, Documents and Process with @canadianvibeswithjasmine
# Counter({'watched': 1, 'get': 1, 'us': 1, 'visa': 1, 'student': 1, 'canada': 1, 'documents': 1, 'process': 1, 'canadianvibeswithjasmine': 1})
#
# Watched HOW TO GET USA ðŸ‡ºðŸ‡¸ VISA AS STUDENT IN CANADA ðŸ‡¨ðŸ‡¦| FULL PROCESS AND DOCUMENTS LIST | STUDENT VLOGS
# Counter({'student': 2, 'watched': 1, 'get': 1, 'usa': 1, 'ðÿ‡ºðÿ‡¸': 1, 'visa': 1, 'canada': 1, 'ðÿ‡¨ðÿ‡¦': 1, 'full': 1, 'process': 1, 'documents': 1, 'list': 1, 'vlogs': 1})
#
# Watched Do I Wanna Know?
# Counter({'watched': 1, 'wanna': 1, 'know': 1})
#
# Watched Watermelon Sugar
# Counter({'watched': 1, 'watermelon': 1, 'sugar': 1})
#
# Watched Levitating (feat. DaBaby)
# Counter({'watched': 1, 'levitating': 1, 'feat': 1, 'dababy': 1})
#
# Watched The Search
# Counter({'watched': 1, 'search': 1})
#
# Watched Cake By The Ocean
# Counter({'watched': 1, 'cake': 1, 'ocean': 1})
#
# Watched Con La Brisa
# Counter({'watched': 1, 'con': 1, 'la': 1, 'brisa': 1})
#
# Watched Pasoori
# Counter({'watched': 1, 'pasoori': 1})
#
# Watched Heat Waves
# Counter({'watched': 1, 'heat': 1, 'waves': 1})
#
# Watched Starboy
# Counter({'watched': 1, 'starboy': 1})
#
# Watched Sucker
# Counter({'watched': 1, 'sucker': 1})
#
# Watched RAJA
# Counter({'watched': 1, 'raja': 1})
#
# Watched Fire Again
# Counter({'watched': 1, 'fire': 1})
#
# Watched I Ain't Worried
# Counter({'watched': 1, 'aint': 1, 'worried': 1})
#
# Watched Entertain Me
# Counter({'watched': 1, 'entertain': 1})
#
# Watched Orch Compression
# Counter({'watched': 1, 'orch': 1, 'compression': 1})
#
# Watched Die For You ft. Grabbitz // Official Music Video // VALORANT Champions 2021
# Counter({'watched': 1, 'die': 1, 'ft': 1, 'grabbitz': 1, 'official': 1, 'music': 1, 'video': 1, 'valorant': 1, 'champions': 1, '2021': 1})
#
# Watched Fake It Til You Make It
# Counter({'watched': 1, 'fake': 1, 'til': 1, 'make': 1})
#
# Watched Numb / Encore
# Counter({'watched': 1, 'numb': 1, 'encore': 1})
#
# Watched One More Light
# Counter({'watched': 1, 'one': 1, 'light': 1})
#
# Watched Massive
# Counter({'watched': 1, 'massive': 1})
#
# Watched Leave Out All The Rest
# Counter({'watched': 1, 'leave': 1, 'rest': 1})
#
# Watched Given Up
# Counter({'watched': 1, 'given': 1})
#
# Watched Crawling
# Counter({'watched': 1, 'crawling': 1})
#
# Watched CASTLE OF GLASS
# Counter({'watched': 1, 'castle': 1, 'glass': 1})
#
# Watched Papercut
# Counter({'watched': 1, 'papercut': 1})
#
# Watched BURN IT DOWN
# Counter({'watched': 1, 'burn': 1})
#
# Watched Breaking the Habit
# Counter({'watched': 1, 'breaking': 1, 'habit': 1})
#
# Watched New Divide
# Counter({'watched': 1, 'new': 1, 'divide': 1})
#
# Watched Lost
# Counter({'watched': 1, 'lost': 1})
#
# Watched Fighting Myself
# Counter({'watched': 1, 'fighting': 1})
#
# Watched Nothing CEO Reviews Samsung S23 Ultra
# Counter({'watched': 1, 'nothing': 1, 'ceo': 1, 'reviews': 1, 'samsung': 1, 's23': 1, 'ultra': 1})
#
# Watched Fighting Myself
# Counter({'watched': 1, 'fighting': 1})
#
# Watched Somewhere I Belong
# Counter({'watched': 1, 'somewhere': 1, 'belong': 1})
#
# Watched What I've Done
# Counter({'watched': 1, 'ive': 1, 'done': 1})
#
# Watched Lost
# Counter({'watched': 1, 'lost': 1})
#
# Watched BURN IT DOWN
# Counter({'watched': 1, 'burn': 1})
#
# Watched The Night We Met
# Counter({'watched': 1, 'night': 1, 'met': 1})
#
# Watched RAJA
# Counter({'watched': 1, 'raja': 1})
#
# Watched Fire Again
# Counter({'watched': 1, 'fire': 1})
#
# Watched I Ain't Worried
# Counter({'watched': 1, 'aint': 1, 'worried': 1})
#
# Watched Entertain Me
# Counter({'watched': 1, 'entertain': 1})
#
# Watched Orch Compression
# Counter({'watched': 1, 'orch': 1, 'compression': 1})
#
# Watched Die For You ft. Grabbitz // Official Music Video // VALORANT Champions 2021
# Counter({'watched': 1, 'die': 1, 'ft': 1, 'grabbitz': 1, 'official': 1, 'music': 1, 'video': 1, 'valorant': 1, 'champions': 1, '2021': 1})
#
# Watched The Jonas Brothers Dish on The Album and Accidentally Predicting the Future in "Year 3000"
# Counter({'watched': 1, 'jonas': 1, 'brothers': 1, 'dish': 1, 'album': 1, 'accidentally': 1, 'predicting': 1, 'future': 1, 'year': 1, '3000': 1})
#
# Watched bbno$, Yung Bae & Billy Marchiafava - Bad Boy (Official Video)
# Counter({'watched': 1, 'bbno': 1, 'yung': 1, 'bae': 1, 'billy': 1, 'marchiafava': 1, 'bad': 1, 'boy': 1, 'official': 1, 'video': 1})
#
# Watched IS LIGHT ARMOR THE *NEW* META ??? | SEN TenZ
# Counter({'watched': 1, 'light': 1, 'armor': 1, 'new': 1, 'meta': 1, 'sen': 1, 'tenz': 1})
#
# Watched The AI Assistant Battle! (2023)
# Counter({'watched': 1, 'ai': 1, 'assistant': 1, 'battle': 1, '2023': 1})
#
# Watched If you can fix this PC, itâ€™s yours! - Origin Chronos V3
# Counter({'watched': 1, 'fix': 1, 'pc': 1, 'itâ€™s': 1, 'origin': 1, 'chronos': 1, 'v3': 1})
#
# Watched Can a Gaming PC Survive the North Pole?
# Counter({'watched': 1, 'gaming': 1, 'pc': 1, 'survive': 1, 'north': 1, 'pole': 1})
#
# Watched How it sounds to á¶ **áµ� up 100 Thieves
# Counter({'watched': 1, 'sounds': 1, 'á¶': 1, 'áµ�': 1, '100': 1, 'thieves': 1})
#
# Watched Why is THIS the Best Selling Phone?
# Counter({'watched': 1, 'best': 1, 'selling': 1, 'phone': 1})
#
# Watched BACK-TO-BACK WINS AT OLD TRAFFORD ðŸ’¥ | Man Utd 2-0 Everton | Highlights
# Counter({'watched': 1, 'backtoback': 1, 'wins': 1, 'old': 1, 'trafford': 1, 'ðÿ’¥': 1, 'man': 1, 'utd': 1, '20': 1, 'everton': 1, 'highlights': 1})
#
# Watched Forgotten Malayalam Movies S04 E08 | Aakasmikam | Malayalam Movie Review Funny | Unni | Devan
# Counter({'malayalam': 2, 'watched': 1, 'forgotten': 1, 'movies': 1, 's04': 1, 'e08': 1, 'aakasmikam': 1, 'movie': 1, 'review': 1, 'funny': 1, 'unni': 1, 'devan': 1})
#
# ...
#
# Watched Did Bezos And Branson Go To Space? Neil deGrasse Tyson Explains The Karman Line
# Counter({'watched': 1, 'bezos': 1, 'branson': 1, 'go': 1, 'space': 1, 'neil': 1, 'degrasse': 1, 'tyson': 1, 'explains': 1, 'karman': 1, 'line': 1})
#
# Watched the final boss of apex
# Counter({'watched': 1, 'final': 1, 'boss': 1, 'apex': 1})
#
# Watched The EASIEST Gaming PC Build Ever!
# Counter({'watched': 1, 'easiest': 1, 'gaming': 1, 'pc': 1, 'build': 1, 'ever': 1})
#
# Watched Our Wedding in Almost a Minute - Tracy Alison Viegas & Kenny Sebastian
# Counter({'watched': 1, 'wedding': 1, 'almost': 1, 'minute': 1, 'tracy': 1, 'alison': 1, 'viegas': 1, 'kenny': 1, 'sebastian': 1})
#
# Watched 35 Hidden Smartphone Tricks.
# Counter({'watched': 1, '35': 1, 'hidden': 1, 'smartphone': 1, 'tricks': 1})
#
# Watched Shroud found the BEST initiator in Valorant!
# Counter({'watched': 1, 'shroud': 1, 'found': 1, 'best': 1, 'initiator': 1, 'valorant': 1})
#
# Watched If the World Was Ending
# Counter({'watched': 1, 'world': 1, 'ending': 1})
#
# Watched Heat Waves
# Counter({'watched': 1, 'heat': 1, 'waves': 1})
#
# Watched Home
# Counter({'watched': 1, 'home': 1})
#
# Watched Take Me To Church
# Counter({'watched': 1, 'take': 1, 'church': 1})
#
# Watched Galway Girl
# Counter({'watched': 1, 'galway': 1, 'girl': 1})
#
# Watched Paint
# Counter({'watched': 1, 'paint': 1})
#
# Watched Someone You Loved
# Counter({'watched': 1, 'someone': 1, 'loved': 1})
#
# Watched i'm so tired...
# Counter({'watched': 1, 'im': 1, 'tired': 1})
#
# Watched Nice To Meet Ya
# Counter({'watched': 1, 'nice': 1, 'meet': 1, 'ya': 1})
#
# Watched 7 Years
# Counter({'watched': 1, '7': 1, 'years': 1})
#
# Watched As the World Caves In
# Counter({'watched': 1, 'world': 1, 'caves': 1})
#
# Watched Underdog
# Counter({'watched': 1, 'underdog': 1})
#
# Watched One Day
# Counter({'watched': 1, 'one': 1, 'day': 1})
#
# Watched Dissolve
# Counter({'watched': 1, 'dissolve': 1})
#
# Watched The A Team
# Counter({'watched': 1, 'team': 1})
#
# Watched Cooler Than Me (Single Mix)
# Counter({'watched': 1, 'cooler': 1, 'single': 1, 'mix': 1})
#
# Watched Leave a Light On
# Counter({'watched': 1, 'leave': 1, 'light': 1})
#
# Visited YouTube Music
# Counter({'visited': 1, 'youtube': 1, 'music': 1})
#
# Watched Cheap vs. Expensive Mousepads (Tenz Tries)
# Counter({'watched': 1, 'cheap': 1, 'vs': 1, 'expensive': 1, 'mousepads': 1, 'tenz': 1, 'tries': 1})
#
# Watched wildest horizon main on kings canyon
# Counter({'watched': 1, 'wildest': 1, 'horizon': 1, 'main': 1, 'kings': 1, 'canyon': 1})
#
# Watched The Man Who Accidentally Killed The Most People In History
# Counter({'watched': 1, 'man': 1, 'accidentally': 1, 'killed': 1, 'people': 1, 'history': 1})
#
# Watched IDK what I just bought... - Internal USB 2.0 SSD?
# Counter({'watched': 1, 'idk': 1, 'bought': 1, 'internal': 1, 'usb': 1, '20': 1, 'ssd': 1})
#
# Watched actually sweating
# Counter({'watched': 1, 'actually': 1, 'sweating': 1})
#
# Watched The Middle East's cold war, explained
# Counter({'watched': 1, 'middle': 1, 'easts': 1, 'cold': 1, 'war': 1, 'explained': 1})
#
# Watched HE GOT SO MAD HE ASKED TO 1V1 | SEN ShahZaM
# Counter({'watched': 1, 'got': 1, 'mad': 1, 'asked': 1, '1v1': 1, 'sen': 1, 'shahzam': 1})
#
# Watched IMMORTAL VS RADIANT
# Counter({'watched': 1, 'immortal': 1, 'vs': 1, 'radiant': 1})
#
# Watched Can a CHEAP 2022 Smartphone beat a 2020 Flagship? ðŸ˜±
# Counter({'watched': 1, 'cheap': 1, '2022': 1, 'smartphone': 1, 'beat': 1, '2020': 1, 'flagship': 1, 'ðÿ˜±': 1})
#
# Watched THE BEST TEAM IN VALORANT RANKED
# Counter({'watched': 1, 'best': 1, 'team': 1, 'valorant': 1, 'ranked': 1})
#
# Watched They Discontinued This Before I Could Buy One! - Hisense U9DG
# Counter({'watched': 1, 'discontinued': 1, 'could': 1, 'buy': 1, 'one': 1, 'hisense': 1, 'u9dg': 1})
#
# Watched KYEDAE SURPRISED ME WITH A PUPPY !!! | SEN TenZ
# Counter({'watched': 1, 'kyedae': 1, 'surprised': 1, 'puppy': 1, 'sen': 1, 'tenz': 1})
#
# Watched what predator ranked actually feels like
# Counter({'watched': 1, 'predator': 1, 'ranked': 1, 'actually': 1, 'feels': 1, 'like': 1})
#
# Watched THIS MADE ME RECONSIDER MY VALORANT CAREER | SEN ShahZaM
# Counter({'watched': 1, 'made': 1, 'reconsider': 1, 'valorant': 1, 'career': 1, 'sen': 1, 'shahzam': 1})
#
# Watched Breaking Valorant Using Only Sage Walls
# Counter({'watched': 1, 'breaking': 1, 'valorant': 1, 'using': 1, 'sage': 1, 'walls': 1})
#
# Watched Why the world's most famous car race is in Monaco
# Counter({'watched': 1, 'worlds': 1, 'famous': 1, 'car': 1, 'race': 1, 'monaco': 1})
#
# Watched Andrew Zimmern Has a Bucket List Moment While Eating Spicy Wings | Hot Ones
# Counter({'watched': 1, 'andrew': 1, 'zimmern': 1, 'bucket': 1, 'list': 1, 'moment': 1, 'eating': 1, 'spicy': 1, 'wings': 1, 'hot': 1, 'ones': 1})
#
# Watched NFL Pros Gabriel Davis and Isaiah Mckenzie Play Truth or Dab | Hot Ones
# Counter({'watched': 1, 'nfl': 1, 'pros': 1, 'gabriel': 1, 'davis': 1, 'isaiah': 1, 'mckenzie': 1, 'play': 1, 'truth': 1, 'dab': 1, 'hot': 1, 'ones': 1})
#
# Watched How the Republican Party went from Lincoln to Trump
# Counter({'watched': 1, 'republican': 1, 'party': 1, 'went': 1, 'lincoln': 1, 'trump': 1})
#
# Watched How America became a superpower
# Counter({'watched': 1, 'america': 1, 'became': 1, 'superpower': 1})
#
# Watched the NRG boys ft. Rogue & sYnceDez
# Counter({'watched': 1, 'nrg': 1, 'boys': 1, 'ft': 1, 'rogue': 1, 'syncedez': 1})
#
# Watched FGB what's your name?
# Counter({'watched': 1, 'fgb': 1, 'whats': 1, 'name': 1})
#
# Watched I Hate It When He's Right... - Epson LS12000 Demo
# Counter({'watched': 1, 'hate': 1, 'hes': 1, 'right': 1, 'epson': 1, 'ls12000': 1, 'demo': 1})
#
# Watched You NEED to see this new Jett glitch...
# Counter({'watched': 1, 'need': 1, 'see': 1, 'new': 1, 'jett': 1, 'glitch': 1})
#
# Watched Marvel Studios' Thor: Love and Thunder | Official Teaser
# Counter({'watched': 1, 'marvel': 1, 'studios': 1, 'thor': 1, 'love': 1, 'thunder': 1, 'official': 1, 'teaser': 1})
#
# Watched Ford's Coolest Electric Truck is from 1978!
# Counter({'watched': 1, 'fords': 1, 'coolest': 1, 'electric': 1, 'truck': 1, '1978': 1})
#
# Watched THE NEW YORU IS INSANE
# Counter({'watched': 1, 'new': 1, 'yoru': 1, 'insane': 1})
#
# Watched horizon is too easy
# Counter({'watched': 1, 'horizon': 1, 'easy': 1})
#
# Watched Making Intel's Worst Product Better.... And Also Worse
# Counter({'watched': 1, 'making': 1, 'intels': 1, 'worst': 1, 'product': 1, 'better': 1, 'also': 1, 'worse': 1})
#
# Watched What a RADIANT Sage looks like...
# Counter({'watched': 1, 'radiant': 1, 'sage': 1, 'looks': 1, 'like': 1})
#
# Watched "sage how did you kill me?"
# Counter({'watched': 1, 'sage': 1, 'kill': 1})
#
# Watched SHROUD VS MIZKIF
# Counter({'watched': 1, 'shroud': 1, 'vs': 1, 'mizkif': 1})
#
# Watched I PLAYED AGAINST THE VALORANT AVENGERS... | SEN ShahZaM
# Counter({'watched': 1, 'played': 1, 'valorant': 1, 'avengers': 1, 'sen': 1, 'shahzam': 1})
#
# Visited YouTube Music
# Counter({'visited': 1, 'youtube': 1, 'music': 1})
#
# Watched "sage that wall is illegal"
# Counter({'watched': 1, 'sage': 1, 'wall': 1, 'illegal': 1})
#
# Watched This is what 5000 hours on Sage looks like...
# Counter({'watched': 1, '5000': 1, 'hours': 1, 'sage': 1, 'looks': 1, 'like': 1})
#
# Watched "sage dont clip that"
# Counter({'watched': 1, 'sage': 1, 'dont': 1, 'clip': 1})
#
# Watched "sage stop playing like grim"
# Counter({'watched': 1, 'sage': 1, 'stop': 1, 'playing': 1, 'like': 1, 'grim': 1})
#
# Watched apex ranked... but elegant
# Counter({'watched': 1, 'apex': 1, 'ranked': 1, 'elegant': 1})
#
# Watched Neon against Radiant players...
# Counter({'watched': 1, 'neon': 1, 'radiant': 1, 'players': 1})
#
# Watched This is one SKETCHY 2000W Power Supply
# Counter({'watched': 1, 'one': 1, 'sketchy': 1, '2000w': 1, 'power': 1, 'supply': 1})
#
# Watched I FOUND THE JAPANESE SHAHZAM | SEN ShahZaM
# Counter({'shahzam': 2, 'watched': 1, 'found': 1, 'japanese': 1, 'sen': 1})
#
# Watched The banned weapon Russia (and the US) wonâ€™t give up
# Counter({'watched': 1, 'banned': 1, 'weapon': 1, 'russia': 1, 'us': 1, 'wonâ€™t': 1, 'give': 1})
#
# Watched filthy horizon user
# Counter({'watched': 1, 'filthy': 1, 'horizon': 1, 'user': 1})
#
# Watched "Sage is a Useless Agent"
# Counter({'watched': 1, 'sage': 1, 'useless': 1, 'agent': 1})
#
# Watched Paint
# Counter({'watched': 1, 'paint': 1})
#
# Watched death bed (coffee for your head)
# Counter({'watched': 1, 'death': 1, 'bed': 1, 'coffee': 1, 'head': 1})
#
# Watched Galway Girl
# Counter({'watched': 1, 'galway': 1, 'girl': 1})
#
# Watched Nice To Meet Ya
# Counter({'watched': 1, 'nice': 1, 'meet': 1, 'ya': 1})
#
# Visited YouTube Music
# Counter({'visited': 1, 'youtube': 1, 'music': 1})
#
# Watched "The Fastest Gaming CPU in the World" - Ryzen 7 5800X3D
# Counter({'watched': 1, 'fastest': 1, 'gaming': 1, 'cpu': 1, 'world': 1, 'ryzen': 1, '7': 1, '5800x3d': 1})
#
# Watched BRIMSTONE IS A DUELIST
# Counter({'watched': 1, 'brimstone': 1, 'duelist': 1})
#
# Watched I AM THE BEST PLAYER IN THE WORLD... on Bind| SEN ShahZaM
# Counter({'watched': 1, 'best': 1, 'player': 1, 'world': 1, 'bind': 1, 'sen': 1, 'shahzam': 1})
#
# Watched I Gave the Pixel Another Chance...
# Counter({'watched': 1, 'gave': 1, 'pixel': 1, 'another': 1, 'chance': 1})
#
# Watched The PCs we ACTUALLY run at home
# Counter({'watched': 1, 'pcs': 1, 'actually': 1, 'run': 1, 'home': 1})
#
# Watched Valorant But Only Using Sage Walls
# Counter({'watched': 1, 'valorant': 1, 'using': 1, 'sage': 1, 'walls': 1})
#
# Watched teamwork makes the dream work
# Counter({'watched': 1, 'teamwork': 1, 'makes': 1, 'dream': 1, 'work': 1})
#
# Watched I Can Die Now. - Intel Fab Tour!
# Counter({'watched': 1, 'die': 1, 'intel': 1, 'fab': 1, 'tour': 1})
#
# Watched What Russia's war means for the International Space Station
# Counter({'watched': 1, 'russias': 1, 'war': 1, 'means': 1, 'international': 1, 'space': 1, 'station': 1})
#
# Watched TARIK AND I VS. SEN TENZ (INTENSE) | SEN ShahZaM
# Counter({'sen': 2, 'watched': 1, 'tarik': 1, 'vs': 1, 'tenz': 1, 'intense': 1, 'shahzam': 1})
#
# Watched A VALORANT RANKED SPEEDRUN
# Counter({'watched': 1, 'valorant': 1, 'ranked': 1, 'speedrun': 1})
#
# Watched The SteamDeck is Incomplete But Fun!
# Counter({'watched': 1, 'steamdeck': 1, 'incomplete': 1, 'fun': 1})
#
# Watched what a PRO Jett player looks like..
# Counter({'watched': 1, 'pro': 1, 'jett': 1, 'player': 1, 'looks': 1, 'like': 1})
#
# Watched I want to love Apple, but theyâ€™re making it hard - Mac Studio SSD Swapping
# Counter({'watched': 1, 'want': 1, 'love': 1, 'apple': 1, 'theyâ€™re': 1, 'making': 1, 'hard': 1, 'mac': 1, 'studio': 1, 'ssd': 1, 'swapping': 1})
#
# Watched TARIK AND I VS. SEN TENZ (INTENSE) | SEN ShahZaM
# Counter({'sen': 2, 'watched': 1, 'tarik': 1, 'vs': 1, 'tenz': 1, 'intense': 1, 'shahzam': 1})
#
# Watched Jab Se Tere Naina
# Counter({'watched': 1, 'jab': 1, 'se': 1, 'tere': 1, 'naina': 1})
#
# Watched Saiyyan
# Counter({'watched': 1, 'saiyyan': 1})
#
# Watched Mere Haath Mein
# Counter({'watched': 1, 'mere': 1, 'haath': 1, 'mein': 1})
#
# Watched O Re Piya
# Counter({'watched': 1, 'piya': 1})
#
# Visited YouTube Music
# Counter({'visited': 1, 'youtube': 1, 'music': 1})
#
# Visited YouTube Music
# Counter({'visited': 1, 'youtube': 1, 'music': 1})
#
# Watched Tu Hi Re (Bombay / Soundtrack Version)
# Counter({'watched': 1, 'tu': 1, 'hi': 1, 'bombay': 1, 'soundtrack': 1, 'version': 1})
#
# Visited YouTube Music
# Counter({'visited': 1, 'youtube': 1, 'music': 1})
#
# Visited YouTube Music
# Counter({'visited': 1, 'youtube': 1, 'music': 1})
#
# Watched Confusing Streamers With Sage Walls
# Counter({'watched': 1, 'confusing': 1, 'streamers': 1, 'sage': 1, 'walls': 1})
#
# Watched Building the $1,000,000 Computer
# Counter({'watched': 1, 'building': 1, '1000000': 1, 'computer': 1})
#
# Watched Lets De - rank again
# Counter({'watched': 1, 'lets': 1, 'de': 1, 'rank': 1})
#
# Watched Secret Saboteurs | Official Trailer
# Counter({'watched': 1, 'secret': 1, 'saboteurs': 1, 'official': 1, 'trailer': 1})
#
# Watched The weekend grind
# Counter({'watched': 1, 'weekend': 1, 'grind': 1})
#
# Watched Lets De - rank again
# Counter({'watched': 1, 'lets': 1, 'de': 1, 'rank': 1})
#
# Watched THE KAYO META
# Counter({'watched': 1, 'kayo': 1, 'meta': 1})
#
# Watched Making Radiants RAGE with Breach ðŸ˜ˆ | SEN ShahZaM
# Counter({'watched': 1, 'making': 1, 'radiants': 1, 'rage': 1, 'breach': 1, 'ðÿ˜ˆ': 1, 'sen': 1, 'shahzam': 1})
#
# Watched heaters on kings canyon
# Counter({'watched': 1, 'heaters': 1, 'kings': 1, 'canyon': 1})
#
# Watched The weekend grind
# Counter({'watched': 1, 'weekend': 1, 'grind': 1})
#
# Watched You're Wrong About Hydrogen Cars - Toyota Mirai
# Counter({'watched': 1, 'youre': 1, 'wrong': 1, 'hydrogen': 1, 'cars': 1, 'toyota': 1, 'mirai': 1})
#
# Watched Apple Makes GREAT Gaming Computers - Gaming on M1 Macbooks
# Counter({'gaming': 2, 'watched': 1, 'apple': 1, 'makes': 1, 'great': 1, 'computers': 1, 'm1': 1, 'macbooks': 1})
#
# Watched Weekend Again..Thank God :D
# Counter({'watched': 1, 'weekend': 1, 'againthank': 1, 'god': 1})
#
# Watched I tested Viral TikTok Life Hacks - are they a SCAM!?
# Counter({'watched': 1, 'tested': 1, 'viral': 1, 'tiktok': 1, 'life': 1, 'hacks': 1, 'scam': 1})
#
# Watched MSI Stealth GS77 Review
# Counter({'watched': 1, 'msi': 1, 'stealth': 1, 'gs77': 1, 'review': 1})
#
# Watched Shroud plays in Fortnite Mondays
# Counter({'watched': 1, 'shroud': 1, 'plays': 1, 'fortnite': 1, 'mondays': 1})
#
# Watched SEN TenZ TRIES FORTNITE FOR THE FIRST TIME !!!
# Counter({'watched': 1, 'sen': 1, 'tenz': 1, 'tries': 1, 'fortnite': 1, 'first': 1, 'time': 1})
#
# Watched THE BATTLE SAGE META | SEN ShahZaM
# Counter({'watched': 1, 'battle': 1, 'sage': 1, 'meta': 1, 'sen': 1, 'shahzam': 1})
#
# Watched Cooling a PC with a 2.5HP Pump
# Counter({'watched': 1, 'cooling': 1, 'pc': 1, '25hp': 1, 'pump': 1})
#
# Watched Cooling a PC with a 2.5HP Pump
# Counter({'watched': 1, 'cooling': 1, 'pc': 1, '25hp': 1, 'pump': 1})
#
# Watched they fear my wattson
# Counter({'watched': 1, 'fear': 1, 'wattson': 1})
#
# Watched We WILL Fix Climate Change!
# Counter({'watched': 1, 'fix': 1, 'climate': 1, 'change': 1})
#
# Watched This is what a RADIANT Raze player looks like...
# Counter({'watched': 1, 'radiant': 1, 'raze': 1, 'player': 1, 'looks': 1, 'like': 1})
#
# Watched The Prettiest Gaming Setup - Intel $5,000 Extreme Tech Upgrade
# Counter({'watched': 1, 'prettiest': 1, 'gaming': 1, 'setup': 1, 'intel': 1, '5000': 1, 'extreme': 1, 'tech': 1, 'upgrade': 1})
#
# Watched Shrouds most INSANE neon game yet..
# Counter({'watched': 1, 'shrouds': 1, 'insane': 1, 'neon': 1, 'game': 1, 'yet': 1})
#
# Watched We Found a Game TenZ is Bad at...
# Counter({'watched': 1, 'found': 1, 'game': 1, 'tenz': 1, 'bad': 1})
#
# Watched chill_valo.exe
# Counter({'watched': 1, 'chillvaloexe': 1})
#
# Watched La La LaðŸ˜ˆ (Valorant Montage)
# Counter({'la': 2, 'watched': 1, 'laðÿ˜ˆ': 1, 'valorant': 1, 'montage': 1})
#
# Watched Barack Obama Goes Back To The White House | GOP Threatens Disney's Tax Breaks
# Counter({'watched': 1, 'barack': 1, 'obama': 1, 'goes': 1, 'back': 1, 'white': 1, 'house': 1, 'gop': 1, 'threatens': 1, 'disneys': 1, 'tax': 1, 'breaks': 1})
#
# Watched I PUT TENZ ON MY BACK. HARD CARRY MODE! | SEN ShahZaM
# Counter({'watched': 1, 'put': 1, 'tenz': 1, 'back': 1, 'hard': 1, 'carry': 1, 'mode': 1, 'sen': 1, 'shahzam': 1})
#
# Watched I PUT TENZ ON MY BACK. HARD CARRY MODE! | SEN ShahZaM
# Counter({'watched': 1, 'put': 1, 'tenz': 1, 'back': 1, 'hard': 1, 'carry': 1, 'mode': 1, 'sen': 1, 'shahzam': 1})
#
# Watched 11 minutes of Shroud playing against other streamers in Apex Legends...
# Counter({'watched': 1, '11': 1, 'minutes': 1, 'shroud': 1, 'playing': 1, 'streamers': 1, 'apex': 1, 'legends': 1})
#
# Watched I've never felt this way before - $60 VR GLOVES!
# Counter({'watched': 1, 'ive': 1, 'never': 1, 'felt': 1, 'way': 1, '60': 1, 'vr': 1, 'gloves': 1})
#
# Watched I Tried to Break a Million Dollar Computer - IBM Z16 Facility Tour!
# Counter({'watched': 1, 'tried': 1, 'break': 1, 'million': 1, 'dollar': 1, 'computer': 1, 'ibm': 1, 'z16': 1, 'facility': 1, 'tour': 1})
#
# Watched Sterling K. Brown Explains His "No Gym" Workout | Train Like A Celebrity | Men's Health
# Counter({'watched': 1, 'sterling': 1, 'k': 1, 'brown': 1, 'explains': 1, 'gym': 1, 'workout': 1, 'train': 1, 'like': 1, 'celebrity': 1, 'mens': 1, 'health': 1})

# %%
# Get stop words
stop_words = set(stopwords.words('english'))

# Define function to clean text
def clean_text(text):
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    # Convert to lowercase
    text = text.lower()
    # Remove stop words
    text = ' '.join([word for word in text.split() if word not in stop_words])
    return text

# Clean the title names
titles_cleaned = [clean_text(title) for title in titles]

# Get the word count for each word
word_counts = Counter(' '.join(titles_cleaned).split())

# Get the top 20 words
top_words = word_counts.most_common(21)

# Print the top 20 words
top_words=top_words[1:]

# %%
# Create lists of words and counts
words = [pair[0] for pair in top_words]
counts = [pair[1] for pair in top_words]

# Create the bar chart
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(words, counts)

# Set the chart title and axis labels
ax.set_title('Top 20 Words in YouTube Video Titles')
ax.set_xlabel('Words')
ax.set_ylabel('Count')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Display the chart
plt.show()
